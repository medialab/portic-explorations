# %% [markdown]
# # Exploration via l'interface de TOFLIT18 datascape : quelles données a-t-on sur la région Poitou dans TOFLIT18 ?
#
# ## Quelles sources sont pertinentes ?
#
# National best guess : non, se fait au niveau france entière
#
# **Local best guess** : oui couvre product x partner x direction.
#
# Objet général : non, au niveau de la france entière
#
# Résumé : non, au niveau de la france entière
#
# **National toutes direction partenaires manquants** : oui, couvre product x partner x direction pour toute la france + quelques partenaires.
#
# National toutes directions tous partenaires : non, existe uniquement pour 1750
#
# **Local** : oui, couvre product x partner x direction, mais n'existe que de 1714 à 1780
#
# 1792 first semester : non, toute la france
#
# National partenaires manquants : non, partenaires manquants
#
# 1792-both semester : non, toute la france
#
# Tableau des quantités : non, toute la france
#
# Tableau des quantités : non, toute la france
#
# Tableau des marchandises : non, toute la france
#
# Tableau Général : non, toute la france

# %% [markdown]
# ## Séries temporelles
#
# Réunion de toutes les sources qui ont des choses pour la direction de La Rochelle.
#
# ![](enquetes/toflit-la-rochelle-time-series.png)
#
# [lien vers la visualisation](http://toflit18.medialab.sciences-po.fr/#/exploration/indicators?lines=%5B%7B%22color%22%3A%22%23C14F4C%22%2C%22direction%22%3A%22La_Rochelle%22%2C%22sourceType%22%3A%22Local%22%7D%2C%7B%22color%22%3A%22%23504342%22%2C%22direction%22%3A%22La_Rochelle%22%2C%22sourceType%22%3A%22Local%20best%20guess%22%7D%2C%7B%22color%22%3A%22%23A563B7%22%2C%22direction%22%3A%22La_Rochelle%22%2C%22sourceType%22%3A%22National%20toutes%20directions%20partenaires%20manquants%22%7D%5D)
#
# Notes :
#
# * pour la fin 1780, uniquement des données de la source "National toutes directions partenaire manquant" ?

# %% [markdown]
# # Produits
#
# ## Approche autour des années 1787-1789
#
# ![](enquetes/toflit_products_1787-1789_simplification_national_toutes_directions_partenaires_manquants.png)
#
# [Lien vers la visualisation](http://toflit18.medialab.sciences-po.fr/#/exploration/terms?nodeSize=flows&edgeSize=flows&labelThreshold=3&labelSizeRatio=2&classification=product_simplification&sourceType=National%20toutes%20directions%20partenaires%20manquants&childClassification=product_sitc_simplEN&direction=La_Rochelle&kind=total&dateMin=1787&dateMax=1789)
#
# Notes :
#
# * pour la fin 1780, uniquement des données de la source "National toutes directions partenaire manquant" ?
# * croisement avec la normalisation Navigo ?

# %% [markdown]
# ## Réseau des partenaires
#
# ### Approche autour des années 1787-1789
#
# | dates | source | groupement des partenaires |
# |---|---|---|
# | 1787-1789 | Toutes directions partenaires manquants | Grouping |
#
# ![](enquetes/toflit_network_1787-1789_grouping_national_toutes_directions_partenaires_manquants.png)
#
#
# [Lien vers la visualisation](http://toflit18.medialab.sciences-po.fr/#/exploration/network?classification=partner_grouping&sourceType=National%20toutes%20directions%20partenaires%20manquants&kind=total&dateMin=1787&dateMax=1789&nodeSize=flows&edgeSize=flows&labelThreshold=5&labelSizeRatio=2)
#
# | dates | source | groupement des partenaires |
# |---|---|---|
# | 1787-1789 | Toutes directions partenaires manquants | Normalisation orthographique |
#
# ![](enquetes/toflit_network_1787-1789_orthographic_national_toutes_directions_partenaires_manquants.png)
#
#
# [Lien vers la visualisation](http://toflit18.medialab.sciences-po.fr/#/exploration/network?classification=partner_orthographic&sourceType=National%20toutes%20directions%20partenaires%20manquants&kind=total&dateMin=1787&dateMax=1789&nodeSize=flows&edgeSize=flows&labelThreshold=5&labelSizeRatio=2)
#
#
# | dates | source | groupement des partenaires |
# |---|---|---|
# | 1787-1789 | Toutes directions partenaires manquants | Simplification |
#
# ![](enquetes/toflit_network_1787-1789_simplification_national_toutes_directions_partenaires_manquants.png)
#
#
# [Lien vers la visualisation](http://toflit18.medialab.sciences-po.fr/#/exploration/network?classification=partner_simplification&sourceType=National%20toutes%20directions%20partenaires%20manquants&kind=total&dateMin=1787&dateMax=1789&nodeSize=flows&edgeSize=flows&labelThreshold=5&labelSizeRatio=2)

# %%
# bootstrapping du client
from lib.client import Api
import json

client = Api()

client.toflit.get_locations('partner_simplification', {
    "partnerClassification":None,
    "kind":"total",
    "sourceType":"National toutes directions partenaires manquants",
    "dateMin": "1750",
    "dateMax": "1780"
})
# Out:
# [{'partner': 'Angleterre',
#   'region': 'Rouen',
#   'count': 97,
#   'value': 5492227.729034424},
#  {'partner': 'Angleterre',
#   'region': 'Caen',
#   'count': 49,
#   'value': 290793.4506378174},
#  {'partner': 'Angleterre',
#   'region': 'Amiens',
#   'count': 117,
#   'value': 4357377.050231934},
#  {'partner': 'Angleterre',
#   'region': 'Bordeaux',
#   'count': 42,
#   'value': 4428339.0498046875},
#  {'partner': 'Angleterre', 'region': 'Narbonne', 'count': 1, 'value': 11300},
#  {'partner': 'Angleterre',
#   'region': 'Marseille',
#   'count': 31,
#   'value': 615680.6399307251},
#  {'partner': 'Angleterre',
#   'region': 'Saint-Quentin',
#   'count': 5,
#   'value': 62215},
#  {'partner': 'Angleterre',
#   'region': 'Montpellier',
#   'count': 14,
#   'value': 1544591.2016143799},
#  {'partner': 'Angleterre',
#   'region': 'Nantes',
#   'count': 45,
#   'value': 907683.0400390625},
#  {'partner': 'Angleterre', 'region': 'Paris', 'count': 20, 'value': 599963},
#  {'partner': 'Angleterre', 'region': 'Châlons', 'count': 2, 'value': 423218},
#  {'partner': 'Angleterre', 'region': 'Bourgogne', 'count': 2, 'value': 1080},
#  {'partner': 'Angleterre',
#   'region': 'Rennes',
#   'count': 49,
#   'value': 1179515.001373291},
#  {'partner': 'Angleterre', 'region': 'Flandre', 'count': 2, 'value': 863532},
#  {'partner': 'Angleterre',
#   'region': 'Bayonne',
#   'count': 9,
#   'value': 157067.19921875},
#  {'partner': 'Angleterre',
#   'region': 'La Rochelle',
#   'count': 10,
#   'value': 662164.5747070312},
#  {'partner': 'Angleterre', 'region': 'Lyon', 'count': 1, 'value': 59085},
#  {'partner': 'Flandre',
#   'region': 'Flandre',
#   'count': 527,
#   'value': 4078534.435720086},
#  {'partner': 'Flandre',
#   'region': 'Charleville',
#   'count': 37,
#   'value': 46944.24001502991},
#  {'partner': 'Flandre',
#   'region': 'Saint-Quentin',
#   'count': 281,
#   'value': 1230017.8880143166},
#  {'partner': 'Flandre',
#   'region': 'Nantes',
#   'count': 39,
#   'value': 667096.0367584229},
#  {'partner': 'Flandre',
#   'region': 'Châlons',
#   'count': 52,
#   'value': 225386.45010375977},
#  {'partner': 'Flandre',
#   'region': 'Bourgogne',
#   'count': 22,
#   'value': 81599.75001573563},
#  {'partner': 'Flandre', 'region': 'Bayonne', 'count': 6, 'value': 426772},
#  {'partner': 'Flandre',
#   'region': 'Amiens',
#   'count': 21,
#   'value': 263105.6499633789},
#  {'partner': 'Flandre',
#   'region': 'Rouen',
#   'count': 34,
#   'value': 101947.54999446869},
#  {'partner': 'Flandre', 'region': 'Rennes', 'count': 27, 'value': 612966.25},
#  {'partner': 'Flandre', 'region': 'Lyon', 'count': 23, 'value': 443336.5},
#  {'partner': 'Flandre',
#   'region': 'Bordeaux',
#   'count': 4,
#   'value': 9743.424560546875},
#  {'partner': 'Flandre',
#   'region': 'La Rochelle',
#   'count': 1,
#   'value': 58545.453125}]

# %%
def query_larochellepartners(start="1787", end="1789", source="National toutes directions partenaires manquants", classification='partner_simplification'):
    
    flux = client.toflit.get_locations(classification, {
        "partnerClassification":None,
        "kind":"total",
        "sourceType":source,
        "dateMin":start,
        "dateMax":end
    })

    def filter_to_larochelle (f):
        print(f)
        if ('direction' in f and f['direction'] == 'La Rochelle'):
            return True
        else:
            return False
    # print("")
    print ("Recherche de partenaires de la direction de la Rochelle de " + start + " à " + end + " selon la source " + source + "(classification : " + classification + ")")
    # print("")
    if (flux):
        flux = filter(filter_to_larochelle, flux)
        # for f in list(flux):
        #     print( f['partner'] + '(' + str(f['count']) + ' flux)')
        return list(flux)
    else :
        # print("Pas de résultats")
        return None
        
# query_larochellepartners(start="1787", end="1789", source="National toutes directions partenaires manquants", classification='partner_simplification')

sources = client.toflit.get_sources_types()
partners_classifications = ["partner_source","partner_orthographic","partner_simplification","partner_africa","partner_grouping","partner_obrien","partner_sourcename","partner_wars"]
years = ["1787", "1788", "1789"]

results = list()
for year in years:
    for source in sources:
        for partner_classification in partners_classifications:
            matching = query_larochellepartners(start=year, end=year, source=source, classification=partner_classification)
            if (matching is not None):
                print("===")
                print("match")
                print("===")
                results.append({
                    "year":year,
                    "classification":partner_classification,
                    "source":source,
                    "flux":matching
                })
# Out:
# Recherche de partenaires de la direction de la Rochelle de 1787 à 1787 selon la source 1792-both semester(classification : partner_source)
# Recherche de partenaires de la direction de la Rochelle de 1787 à 1787 selon la source 1792-both semester(classification : partner_orthographic)
# Recherche de partenaires de la direction de la Rochelle de 1787 à 1787 selon la source 1792-both semester(classification : partner_simplification)
# Recherche de partenaires de la direction de la Rochelle de 1787 à 1787 selon la source 1792-both semester(classification : partner_africa)
# Recherche de partenaires de la direction de la Rochelle de 1787 à 1787 selon la source 1792-both semester(classification : partner_grouping)
# Recherche de partenaires de la direction de la Rochelle de 1787 à 1787 selon la source 1792-both semester(classification : partner_obrien)
# Recherche de partenaires de la direction de la Rochelle de 1787 à 1787 selon la source 1792-both semester(classification : partner_sourcename)
# Recherche de partenaires de la direction de la Rochelle de 1787 à 1787 selon la source 1792-both semester(classification : partner_wars)
# Recherche de partenaires de la direction de la Rochelle de 1787 à 1787 selon la source 1792-first semester(classification : partner_source)
# Recherche de partenaires de la direction de la Rochelle de 1787 à 1787 selon la source 1792-first semester(classification : partner_orthographic)
# Recherche de partenaires de la direction de la Rochelle de 1787 à 1787 selon la source 1792-first semester(classification : partner_simplification)
# Recherche de partenaires de la direction de la Rochelle de 1787 à 1787 selon la source 1792-first semester(classification : partner_africa)
# Recherche de partenaires de la direction de la Rochelle de 1787 à 1787 selon la source 1792-first semester(classification : partner_grouping)
# Recherche de partenaires de la direction de la Rochelle de 1787 à 1787 selon la source 1792-first semester(classification : partner_obrien)
# Recherche de partenaires de la direction de la Rochelle de 1787 à 1787 selon la source 1792-first semester(classification : partner_sourcename)
# Recherche de partenaires de la direction de la Rochelle de 1787 à 1787 selon la source 1792-first semester(classification : partner_wars)
# Recherche de partenaires de la direction de la Rochelle de 1787 à 1787 selon la source Best Guess customs region product x partner(classification : partner_source)
# Recherche de partenaires de la direction de la Rochelle de 1787 à 1787 selon la source Best Guess customs region product x partner(classification : partner_orthographic)
# {'partner': 'Possessions suédoises', 'region': "Colonies Françaises de l'Amérique", 'count': 27, 'value': 625378}
# {'partner': "Possessions des États-Unis d'Amérique", 'region': "Colonies Françaises de l'Amérique", 'count': 74, 'value': 16988110}
# {'partner': 'Possessions anglaises', 'region': "Colonies Françaises de l'Amérique", 'count': 67, 'value': 7306915}
# {'partner': 'Possessions espagnoles', 'region': "Colonies Françaises de l'Amérique", 'count': 77, 'value': 5809081}
# {'partner': 'Possessions danoises', 'region': "Colonies Françaises de l'Amérique", 'count': 43, 'value': 408572}
# {'partner': 'Possessions hollandaises', 'region': "Colonies Françaises de l'Amérique", 'count': 73, 'value': 2648895}
# {'partner': 'Possessions portugaises', 'region': "Colonies Françaises de l'Amérique", 'count': 13, 'value': 71000}
# ===
# match
# ===
# Recherche de partenaires de la direction de la Rochelle de 1787 à 1787 selon la source Best Guess customs region product x partner(classification : partner_simplification)
# {'partner': 'Colonies suédoises', 'region': "Colonies Françaises de l'Amérique", 'count': 27, 'value': 625378}
# {'partner': "Colonies des États-Unis d'Amérique", 'region': "Colonies Françaises de l'Amérique", 'count': 74, 'value': 16988110}
# {'partner': 'Colonies anglaises', 'region': "Colonies Françaises de l'Amérique", 'count': 67, 'value': 7306915}
# {'partner': 'Colonies espagnoles', 'region': "Colonies Françaises de l'Amérique", 'count': 77, 'value': 5809081}
# {'partner': 'Colonies danoises', 'region': "Colonies Françaises de l'Amérique", 'count': 43, 'value': 408572}
# {'partner': 'Colonies hollandaises', 'region': "Colonies Françaises de l'Amérique", 'count': 73, 'value': 2648895}
# {'partner': 'Colonies portugaises', 'region': "Colonies Françaises de l'Amérique", 'count': 13, 'value': 71000}
# ===
# match
# ===
# Recherche de partenaires de la direction de la Rochelle de 1787 à 1787 selon la source Best Guess customs region product x partner(classification : partner_africa)
# {'partner': 'Other outre-mers', 'region': "Colonies Françaises de l'Amérique", 'count': 374, 'value': 33857951}
# ===
# match
# ===
# Recherche de partenaires de la direction de la Rochelle de 1787 à 1787 selon la source Best Guess customs region product x partner(classification : partner_grouping)
# {'partner': 'Outre-mers', 'region': "Colonies Françaises de l'Amérique", 'count': 374, 'value': 33857951}
# ===
# match
# ===
# Recherche de partenaires de la direction de la Rochelle de 1787 à 1787 selon la source Best Guess customs region product x partner(classification : partner_obrien)
# {'partner': 'Colonies suédoises', 'region': "Colonies Françaises de l'Amérique", 'count': 27, 'value': 625378}
# {'partner': "Colonies des États-Unis d'Amérique", 'region': "Colonies Françaises de l'Amérique", 'count': 74, 'value': 16988110}
# {'partner': 'Colonies anglaises', 'region': "Colonies Françaises de l'Amérique", 'count': 67, 'value': 7306915}
# {'partner': 'Colonies espagnoles', 'region': "Colonies Françaises de l'Amérique", 'count': 77, 'value': 5809081}
# {'partner': 'Colonies danoises', 'region': "Colonies Françaises de l'Amérique", 'count': 43, 'value': 408572}
# {'partner': 'Colonies hollandaises', 'region': "Colonies Françaises de l'Amérique", 'count': 73, 'value': 2648895}
# {'partner': 'Colonies portugaises', 'region': "Colonies Françaises de l'Amérique", 'count': 13, 'value': 71000}
# ===
# match
# ===
# Recherche de partenaires de la direction de la Rochelle de 1787 à 1787 selon la source Best Guess customs region product x partner(classification : partner_sourcename)
# {'partner': 'Outre-mers', 'region': "Colonies Françaises de l'Amérique", 'count': 374, 'value': 33857951}
# ===
# match
# ===
# Recherche de partenaires de la direction de la Rochelle de 1787 à 1787 selon la source Best Guess customs region product x partner(classification : partner_wars)
# {'partner': 'Suède et ses colonies', 'region': "Colonies Françaises de l'Amérique", 'count': 27, 'value': 625378}
# {'partner': "États-Unis d'Amérique et ses colonies", 'region': "Colonies Françaises de l'Amérique", 'count': 74, 'value': 16988110}
# {'partner': 'Angleterre et ses colonies', 'region': "Colonies Françaises de l'Amérique", 'count': 67, 'value': 7306915}
# {'partner': 'Espagne et ses colonies', 'region': "Colonies Françaises de l'Amérique", 'count': 77, 'value': 5809081}
# {'partner': 'Danemark et ses colonies', 'region': "Colonies Françaises de l'Amérique", 'count': 43, 'value': 408572}
# {'partner': 'Hollande et ses colonies', 'region': "Colonies Françaises de l'Amérique", 'count': 73, 'value': 2648895}
# {'partner': 'Portugal et ses colonies', 'region': "Colonies Françaises de l'Amérique", 'count': 13, 'value': 71000}
# ===
# match
# ===
# Recherche de partenaires de la direction de la Rochelle de 1787 à 1787 selon la source Best Guess national customs region(classification : partner_source)
# Recherche de partenaires de la direction de la Rochelle de 1787 à 1787 selon la source Best Guess national customs region(classification : partner_orthographic)
# {'partner': 'Angleterre', 'region': 'Paris', 'count': 7, 'value': 1006855}
# {'partner': 'Angleterre', 'region': 'Montpellier', 'count': 14, 'value': 642000}
# {'partner': 'Angleterre', 'region': 'Flandre', 'count': 115, 'value': 18880000}
# {'partner': 'Angleterre', 'region': 'Amiens', 'count': 52, 'value': 7024000}
# {'partner': 'Angleterre', 'region': 'Marseille', 'count': 33, 'value': 2062000}
# {'partner': 'Angleterre', 'region': 'Rouen', 'count': 74, 'value': 11923000}
# {'partner': 'Angleterre', 'region': 'Caen', 'count': 22, 'value': 755000}
# {'partner': 'Angleterre', 'region': 'Rennes', 'count': 58, 'value': 4146000}
# {'partner': 'Angleterre', 'region': 'La Rochelle', 'count': 16, 'value': 1604000}
# {'partner': 'Angleterre', 'region': 'Bordeaux', 'count': 49, 'value': 12391000}
# {'partner': 'Angleterre', 'region': 'France', 'count': 22, 'value': 1040000}
# {'partner': 'Voitures diverses', 'region': 'Nantes', 'count': 2, 'value': 100800}
# {'partner': 'Saint-Domingue', 'region': 'France', 'count': 51, 'value': 411910}
# {'partner': 'Saint-Domingue', 'region': 'Saint-Malo', 'count': 37, 'value': 327944}
# {'partner': 'Saint-Domingue', 'region': 'La Rochelle', 'count': 23, 'value': 94207}
# {'partner': 'Saint-Domingue', 'region': 'Bayonne', 'count': 32, 'value': 287934}
# {'partner': 'Saint-Domingue', 'region': 'Le Havre', 'count': 134, 'value': 5534840}
# {'partner': 'Saint-Domingue', 'region': 'Nantes', 'count': 163, 'value': 5324674}
# {'partner': 'Saint-Domingue', 'region': 'Bordeaux', 'count': 203, 'value': 29297995}
# {'partner': 'Martinique', 'region': 'France', 'count': 16, 'value': 54153}
# {'partner': 'Martinique', 'region': 'Bayonne', 'count': 27, 'value': 95000}
# {'partner': 'Martinique', 'region': 'Le Havre', 'count': 110, 'value': 2626188}
# {'partner': 'Martinique', 'region': 'Nantes', 'count': 100, 'value': 748925}
# {'partner': 'Martinique', 'region': 'Bordeaux', 'count': 165, 'value': 4981220}
# {'partner': 'Guadeloupe', 'region': 'Saint-Malo', 'count': 14, 'value': 34334}
# {'partner': 'Guadeloupe', 'region': 'Bayonne', 'count': 22, 'value': 55712}
# {'partner': 'Guadeloupe', 'region': 'Le Havre', 'count': 88, 'value': 1168407}
# {'partner': 'Guadeloupe', 'region': 'Nantes', 'count': 106, 'value': 358803}
# {'partner': 'Guadeloupe', 'region': 'Bordeaux', 'count': 171, 'value': 2774051}
# {'partner': 'Cayenne-Guyane', 'region': 'Bordeaux', 'count': 118, 'value': 290016}
# {'partner': 'Sénégal et Guinée', 'region': 'France', 'count': 55, 'value': 725772}
# {'partner': 'Sénégal et Guinée', 'region': 'Saint-Malo', 'count': 40, 'value': 637993}
# {'partner': 'Sénégal et Guinée', 'region': 'La Rochelle', 'count': 68, 'value': 2821563}
# {'partner': 'Sénégal et Guinée', 'region': 'Bayonne', 'count': 10, 'value': 22797}
# {'partner': 'Sénégal et Guinée', 'region': 'Le Havre', 'count': 108, 'value': 5630191}
# {'partner': 'Sénégal et Guinée', 'region': 'Nantes', 'count': 122, 'value': 4875886}
# {'partner': 'Sénégal et Guinée', 'region': 'Bordeaux', 'count': 155, 'value': 2834629}
# {'partner': 'Tobago', 'region': 'Le Havre', 'count': 71, 'value': 159489}
# ===
# match
# ===
# Recherche de partenaires de la direction de la Rochelle de 1787 à 1787 selon la source Best Guess national customs region(classification : partner_simplification)
# {'partner': 'Angleterre', 'region': 'Paris', 'count': 7, 'value': 1006855}
# {'partner': 'Angleterre', 'region': 'Montpellier', 'count': 14, 'value': 642000}
# {'partner': 'Angleterre', 'region': 'Flandre', 'count': 115, 'value': 18880000}
# {'partner': 'Angleterre', 'region': 'Amiens', 'count': 52, 'value': 7024000}
# {'partner': 'Angleterre', 'region': 'Marseille', 'count': 33, 'value': 2062000}
# {'partner': 'Angleterre', 'region': 'Rouen', 'count': 74, 'value': 11923000}
# {'partner': 'Angleterre', 'region': 'Caen', 'count': 22, 'value': 755000}
# {'partner': 'Angleterre', 'region': 'Rennes', 'count': 58, 'value': 4146000}
# {'partner': 'Angleterre', 'region': 'La Rochelle', 'count': 16, 'value': 1604000}
# {'partner': 'Angleterre', 'region': 'Bordeaux', 'count': 49, 'value': 12391000}
# {'partner': 'Angleterre', 'region': 'France', 'count': 22, 'value': 1040000}
# {'partner': 'Voitures diverses', 'region': 'Nantes', 'count': 2, 'value': 100800}
# {'partner': 'Saint-Domingue', 'region': 'France', 'count': 51, 'value': 411910}
# {'partner': 'Saint-Domingue', 'region': 'Saint-Malo', 'count': 37, 'value': 327944}
# {'partner': 'Saint-Domingue', 'region': 'La Rochelle', 'count': 23, 'value': 94207}
# {'partner': 'Saint-Domingue', 'region': 'Bayonne', 'count': 32, 'value': 287934}
# {'partner': 'Saint-Domingue', 'region': 'Le Havre', 'count': 134, 'value': 5534840}
# {'partner': 'Saint-Domingue', 'region': 'Nantes', 'count': 163, 'value': 5324674}
# {'partner': 'Saint-Domingue', 'region': 'Bordeaux', 'count': 203, 'value': 29297995}
# {'partner': 'Martinique', 'region': 'France', 'count': 16, 'value': 54153}
# {'partner': 'Martinique', 'region': 'Bayonne', 'count': 27, 'value': 95000}
# {'partner': 'Martinique', 'region': 'Le Havre', 'count': 110, 'value': 2626188}
# {'partner': 'Martinique', 'region': 'Nantes', 'count': 100, 'value': 748925}
# {'partner': 'Martinique', 'region': 'Bordeaux', 'count': 165, 'value': 4981220}
# {'partner': 'Guadeloupe', 'region': 'Saint-Malo', 'count': 14, 'value': 34334}
# {'partner': 'Guadeloupe', 'region': 'Bayonne', 'count': 22, 'value': 55712}
# {'partner': 'Guadeloupe', 'region': 'Le Havre', 'count': 88, 'value': 1168407}
# {'partner': 'Guadeloupe', 'region': 'Nantes', 'count': 106, 'value': 358803}
# {'partner': 'Guadeloupe', 'region': 'Bordeaux', 'count': 171, 'value': 2774051}
# {'partner': 'Cayenne et Guyane', 'region': 'Bordeaux', 'count': 118, 'value': 290016}
# {'partner': 'Guinée et Sénégal', 'region': 'France', 'count': 55, 'value': 725772}
# {'partner': 'Guinée et Sénégal', 'region': 'Saint-Malo', 'count': 40, 'value': 637993}
# {'partner': 'Guinée et Sénégal', 'region': 'La Rochelle', 'count': 68, 'value': 2821563}
# {'partner': 'Guinée et Sénégal', 'region': 'Bayonne', 'count': 10, 'value': 22797}
# {'partner': 'Guinée et Sénégal', 'region': 'Le Havre', 'count': 108, 'value': 5630191}
# {'partner': 'Guinée et Sénégal', 'region': 'Nantes', 'count': 122, 'value': 4875886}
# {'partner': 'Guinée et Sénégal', 'region': 'Bordeaux', 'count': 155, 'value': 2834629}
# {'partner': 'Tobago', 'region': 'Le Havre', 'count': 71, 'value': 159489}
# ===
# match
# ===
# Recherche de partenaires de la direction de la Rochelle de 1787 à 1787 selon la source Best Guess national customs region(classification : partner_africa)
# {'partner': 'Not Outre-mers', 'region': 'Paris', 'count': 7, 'value': 1006855}
# {'partner': 'Not Outre-mers', 'region': 'Montpellier', 'count': 14, 'value': 642000}
# {'partner': 'Not Outre-mers', 'region': 'Flandre', 'count': 115, 'value': 18880000}
# {'partner': 'Not Outre-mers', 'region': 'Amiens', 'count': 52, 'value': 7024000}
# {'partner': 'Not Outre-mers', 'region': 'Marseille', 'count': 33, 'value': 2062000}
# {'partner': 'Not Outre-mers', 'region': 'Rouen', 'count': 74, 'value': 11923000}
# {'partner': 'Not Outre-mers', 'region': 'Caen', 'count': 22, 'value': 755000}
# {'partner': 'Not Outre-mers', 'region': 'Rennes', 'count': 58, 'value': 4146000}
# {'partner': 'Not Outre-mers', 'region': 'La Rochelle', 'count': 16, 'value': 1604000}
# {'partner': 'Not Outre-mers', 'region': 'Bordeaux', 'count': 49, 'value': 12391000}
# {'partner': 'Not Outre-mers', 'region': 'France', 'count': 22, 'value': 1040000}
# {'partner': 'Not Outre-mers', 'region': 'Nantes', 'count': 2, 'value': 100800}
# {'partner': 'Other outre-mers', 'region': 'France', 'count': 67, 'value': 466063}
# {'partner': 'Other outre-mers', 'region': 'Saint-Malo', 'count': 51, 'value': 362278}
# {'partner': 'Other outre-mers', 'region': 'La Rochelle', 'count': 23, 'value': 94207}
# {'partner': 'Other outre-mers', 'region': 'Bayonne', 'count': 81, 'value': 438646}
# {'partner': 'Other outre-mers', 'region': 'Le Havre', 'count': 403, 'value': 9488924}
# {'partner': 'Other outre-mers', 'region': 'Nantes', 'count': 369, 'value': 6432402}
# {'partner': 'Other outre-mers', 'region': 'Bordeaux', 'count': 657, 'value': 37343282}
# {'partner': 'Africa', 'region': 'France', 'count': 55, 'value': 725772}
# {'partner': 'Africa', 'region': 'Saint-Malo', 'count': 40, 'value': 637993}
# {'partner': 'Africa', 'region': 'La Rochelle', 'count': 68, 'value': 2821563}
# {'partner': 'Africa', 'region': 'Bayonne', 'count': 10, 'value': 22797}
# {'partner': 'Africa', 'region': 'Le Havre', 'count': 108, 'value': 5630191}
# {'partner': 'Africa', 'region': 'Nantes', 'count': 122, 'value': 4875886}
# {'partner': 'Africa', 'region': 'Bordeaux', 'count': 155, 'value': 2834629}
# ===
# match
# ===
# Recherche de partenaires de la direction de la Rochelle de 1787 à 1787 selon la source Best Guess national customs region(classification : partner_grouping)
# {'partner': 'Angleterre', 'region': 'Paris', 'count': 7, 'value': 1006855}
# {'partner': 'Angleterre', 'region': 'Montpellier', 'count': 14, 'value': 642000}
# {'partner': 'Angleterre', 'region': 'Flandre', 'count': 115, 'value': 18880000}
# {'partner': 'Angleterre', 'region': 'Amiens', 'count': 52, 'value': 7024000}
# {'partner': 'Angleterre', 'region': 'Marseille', 'count': 33, 'value': 2062000}
# {'partner': 'Angleterre', 'region': 'Rouen', 'count': 74, 'value': 11923000}
# {'partner': 'Angleterre', 'region': 'Caen', 'count': 22, 'value': 755000}
# {'partner': 'Angleterre', 'region': 'Rennes', 'count': 58, 'value': 4146000}
# {'partner': 'Angleterre', 'region': 'La Rochelle', 'count': 16, 'value': 1604000}
# {'partner': 'Angleterre', 'region': 'Bordeaux', 'count': 49, 'value': 12391000}
# {'partner': 'Angleterre', 'region': 'France', 'count': 22, 'value': 1040000}
# {'partner': 'Divers', 'region': 'Nantes', 'count': 2, 'value': 100800}
# {'partner': 'Amériques', 'region': 'France', 'count': 67, 'value': 466063}
# {'partner': 'Amériques', 'region': 'Saint-Malo', 'count': 51, 'value': 362278}
# {'partner': 'Amériques', 'region': 'La Rochelle', 'count': 23, 'value': 94207}
# {'partner': 'Amériques', 'region': 'Bayonne', 'count': 81, 'value': 438646}
# {'partner': 'Amériques', 'region': 'Le Havre', 'count': 403, 'value': 9488924}
# {'partner': 'Amériques', 'region': 'Nantes', 'count': 369, 'value': 6432402}
# {'partner': 'Amériques', 'region': 'Bordeaux', 'count': 657, 'value': 37343282}
# {'partner': 'Afrique', 'region': 'France', 'count': 55, 'value': 725772}
# {'partner': 'Afrique', 'region': 'Saint-Malo', 'count': 40, 'value': 637993}
# {'partner': 'Afrique', 'region': 'La Rochelle', 'count': 68, 'value': 2821563}
# {'partner': 'Afrique', 'region': 'Bayonne', 'count': 10, 'value': 22797}
# {'partner': 'Afrique', 'region': 'Le Havre', 'count': 108, 'value': 5630191}
# {'partner': 'Afrique', 'region': 'Nantes', 'count': 122, 'value': 4875886}
# {'partner': 'Afrique', 'region': 'Bordeaux', 'count': 155, 'value': 2834629}
# ===
# match
# ===
# Recherche de partenaires de la direction de la Rochelle de 1787 à 1787 selon la source Best Guess national customs region(classification : partner_obrien)
# {'partner': 'Angleterre', 'region': 'Paris', 'count': 7, 'value': 1006855}
# {'partner': 'Angleterre', 'region': 'Montpellier', 'count': 14, 'value': 642000}
# {'partner': 'Angleterre', 'region': 'Flandre', 'count': 115, 'value': 18880000}
# {'partner': 'Angleterre', 'region': 'Amiens', 'count': 52, 'value': 7024000}
# {'partner': 'Angleterre', 'region': 'Marseille', 'count': 33, 'value': 2062000}
# {'partner': 'Angleterre', 'region': 'Rouen', 'count': 74, 'value': 11923000}
# {'partner': 'Angleterre', 'region': 'Caen', 'count': 22, 'value': 755000}
# {'partner': 'Angleterre', 'region': 'Rennes', 'count': 58, 'value': 4146000}
# {'partner': 'Angleterre', 'region': 'La Rochelle', 'count': 16, 'value': 1604000}
# {'partner': 'Angleterre', 'region': 'Bordeaux', 'count': 49, 'value': 12391000}
# {'partner': 'Angleterre', 'region': 'France', 'count': 22, 'value': 1040000}
# {'partner': 'Voitures diverses', 'region': 'Nantes', 'count': 2, 'value': 100800}
# {'partner': 'Saint-Domingue', 'region': 'France', 'count': 51, 'value': 411910}
# {'partner': 'Saint-Domingue', 'region': 'Saint-Malo', 'count': 37, 'value': 327944}
# {'partner': 'Saint-Domingue', 'region': 'La Rochelle', 'count': 23, 'value': 94207}
# {'partner': 'Saint-Domingue', 'region': 'Bayonne', 'count': 32, 'value': 287934}
# {'partner': 'Saint-Domingue', 'region': 'Le Havre', 'count': 134, 'value': 5534840}
# {'partner': 'Saint-Domingue', 'region': 'Nantes', 'count': 163, 'value': 5324674}
# {'partner': 'Saint-Domingue', 'region': 'Bordeaux', 'count': 203, 'value': 29297995}
# {'partner': 'Martinique', 'region': 'France', 'count': 16, 'value': 54153}
# {'partner': 'Martinique', 'region': 'Bayonne', 'count': 27, 'value': 95000}
# {'partner': 'Martinique', 'region': 'Le Havre', 'count': 110, 'value': 2626188}
# {'partner': 'Martinique', 'region': 'Nantes', 'count': 100, 'value': 748925}
# {'partner': 'Martinique', 'region': 'Bordeaux', 'count': 165, 'value': 4981220}
# {'partner': 'Guadeloupe', 'region': 'Saint-Malo', 'count': 14, 'value': 34334}
# {'partner': 'Guadeloupe', 'region': 'Bayonne', 'count': 22, 'value': 55712}
# {'partner': 'Guadeloupe', 'region': 'Le Havre', 'count': 88, 'value': 1168407}
# {'partner': 'Guadeloupe', 'region': 'Nantes', 'count': 106, 'value': 358803}
# {'partner': 'Guadeloupe', 'region': 'Bordeaux', 'count': 171, 'value': 2774051}
# {'partner': 'Cayenne et Guyane', 'region': 'Bordeaux', 'count': 118, 'value': 290016}
# {'partner': 'Guinée et Sénégal', 'region': 'France', 'count': 55, 'value': 725772}
# {'partner': 'Guinée et Sénégal', 'region': 'Saint-Malo', 'count': 40, 'value': 637993}
# {'partner': 'Guinée et Sénégal', 'region': 'La Rochelle', 'count': 68, 'value': 2821563}
# {'partner': 'Guinée et Sénégal', 'region': 'Bayonne', 'count': 10, 'value': 22797}
# {'partner': 'Guinée et Sénégal', 'region': 'Le Havre', 'count': 108, 'value': 5630191}
# {'partner': 'Guinée et Sénégal', 'region': 'Nantes', 'count': 122, 'value': 4875886}
# {'partner': 'Guinée et Sénégal', 'region': 'Bordeaux', 'count': 155, 'value': 2834629}
# {'partner': 'Tobago', 'region': 'Le Havre', 'count': 71, 'value': 159489}
# ===
# match
# ===
# Recherche de partenaires de la direction de la Rochelle de 1787 à 1787 selon la source Best Guess national customs region(classification : partner_sourcename)
# {'partner': 'Angleterre', 'region': 'Paris', 'count': 7, 'value': 1006855}
# {'partner': 'Angleterre', 'region': 'Montpellier', 'count': 14, 'value': 642000}
# {'partner': 'Angleterre', 'region': 'Flandre', 'count': 115, 'value': 18880000}
# {'partner': 'Angleterre', 'region': 'Amiens', 'count': 52, 'value': 7024000}
# {'partner': 'Angleterre', 'region': 'Marseille', 'count': 33, 'value': 2062000}
# {'partner': 'Angleterre', 'region': 'Rouen', 'count': 74, 'value': 11923000}
# {'partner': 'Angleterre', 'region': 'Caen', 'count': 22, 'value': 755000}
# {'partner': 'Angleterre', 'region': 'Rennes', 'count': 58, 'value': 4146000}
# {'partner': 'Angleterre', 'region': 'La Rochelle', 'count': 16, 'value': 1604000}
# {'partner': 'Angleterre', 'region': 'Bordeaux', 'count': 49, 'value': 12391000}
# {'partner': 'Angleterre', 'region': 'France', 'count': 22, 'value': 1040000}
# {'partner': 'Divers', 'region': 'Nantes', 'count': 2, 'value': 100800}
# {'partner': 'Colonies', 'region': 'France', 'count': 51, 'value': 411910}
# {'partner': 'Colonies', 'region': 'Saint-Malo', 'count': 37, 'value': 327944}
# {'partner': 'Colonies', 'region': 'La Rochelle', 'count': 23, 'value': 94207}
# {'partner': 'Colonies', 'region': 'Bayonne', 'count': 32, 'value': 287934}
# {'partner': 'Colonies', 'region': 'Le Havre', 'count': 134, 'value': 5534840}
# {'partner': 'Colonies', 'region': 'Nantes', 'count': 163, 'value': 5324674}
# {'partner': 'Colonies', 'region': 'Bordeaux', 'count': 203, 'value': 29297995}
# {'partner': 'Outre-mers', 'region': 'France', 'count': 16, 'value': 54153}
# {'partner': 'Outre-mers', 'region': 'Bayonne', 'count': 49, 'value': 150712}
# {'partner': 'Outre-mers', 'region': 'Le Havre', 'count': 269, 'value': 3954084}
# {'partner': 'Outre-mers', 'region': 'Nantes', 'count': 206, 'value': 1107728}
# {'partner': 'Outre-mers', 'region': 'Bordeaux', 'count': 454, 'value': 8045287}
# {'partner': 'Outre-mers', 'region': 'Saint-Malo', 'count': 14, 'value': 34334}
# {'partner': 'Guinée', 'region': 'France', 'count': 55, 'value': 725772}
# {'partner': 'Guinée', 'region': 'Saint-Malo', 'count': 40, 'value': 637993}
# {'partner': 'Guinée', 'region': 'La Rochelle', 'count': 68, 'value': 2821563}
# {'partner': 'Guinée', 'region': 'Bayonne', 'count': 10, 'value': 22797}
# {'partner': 'Guinée', 'region': 'Le Havre', 'count': 108, 'value': 5630191}
# {'partner': 'Guinée', 'region': 'Nantes', 'count': 122, 'value': 4875886}
# {'partner': 'Guinée', 'region': 'Bordeaux', 'count': 155, 'value': 2834629}
# ===
# match
# ===
# Recherche de partenaires de la direction de la Rochelle de 1787 à 1787 selon la source Best Guess national customs region(classification : partner_wars)
# {'partner': 'Angleterre et ses colonies', 'region': 'Paris', 'count': 7, 'value': 1006855}
# {'partner': 'Angleterre et ses colonies', 'region': 'Montpellier', 'count': 14, 'value': 642000}
# {'partner': 'Angleterre et ses colonies', 'region': 'Flandre', 'count': 115, 'value': 18880000}
# {'partner': 'Angleterre et ses colonies', 'region': 'Amiens', 'count': 52, 'value': 7024000}
# {'partner': 'Angleterre et ses colonies', 'region': 'Marseille', 'count': 33, 'value': 2062000}
# {'partner': 'Angleterre et ses colonies', 'region': 'Rouen', 'count': 74, 'value': 11923000}
# {'partner': 'Angleterre et ses colonies', 'region': 'Caen', 'count': 22, 'value': 755000}
# {'partner': 'Angleterre et ses colonies', 'region': 'Rennes', 'count': 58, 'value': 4146000}
# {'partner': 'Angleterre et ses colonies', 'region': 'La Rochelle', 'count': 16, 'value': 1604000}
# {'partner': 'Angleterre et ses colonies', 'region': 'Bordeaux', 'count': 49, 'value': 12391000}
# {'partner': 'Angleterre et ses colonies', 'region': 'France', 'count': 22, 'value': 1040000}
# {'partner': 'Divers', 'region': 'Nantes', 'count': 2, 'value': 100800}
# {'partner': 'Colonies françaises', 'region': 'France', 'count': 122, 'value': 1191835}
# {'partner': 'Colonies françaises', 'region': 'Saint-Malo', 'count': 91, 'value': 1000271}
# {'partner': 'Colonies françaises', 'region': 'La Rochelle', 'count': 91, 'value': 2915770}
# {'partner': 'Colonies françaises', 'region': 'Bayonne', 'count': 91, 'value': 461443}
# {'partner': 'Colonies françaises', 'region': 'Le Havre', 'count': 511, 'value': 15119115}
# {'partner': 'Colonies françaises', 'region': 'Nantes', 'count': 491, 'value': 11308288}
# {'partner': 'Colonies françaises', 'region': 'Bordeaux', 'count': 812, 'value': 40177911}
# ===
# match
# ===
# Recherche de partenaires de la direction de la Rochelle de 1787 à 1787 selon la source Best Guess national partner(classification : partner_source)
# Recherche de partenaires de la direction de la Rochelle de 1787 à 1787 selon la source Best Guess national partner(classification : partner_orthographic)
# Recherche de partenaires de la direction de la Rochelle de 1787 à 1787 selon la source Best Guess national partner(classification : partner_simplification)
# Recherche de partenaires de la direction de la Rochelle de 1787 à 1787 selon la source Best Guess national partner(classification : partner_africa)
# Recherche de partenaires de la direction de la Rochelle de 1787 à 1787 selon la source Best Guess national partner(classification : partner_grouping)
# Recherche de partenaires de la direction de la Rochelle de 1787 à 1787 selon la source Best Guess national partner(classification : partner_obrien)
# Recherche de partenaires de la direction de la Rochelle de 1787 à 1787 selon la source Best Guess national partner(classification : partner_sourcename)
# Recherche de partenaires de la direction de la Rochelle de 1787 à 1787 selon la source Best Guess national partner(classification : partner_wars)
# Recherche de partenaires de la direction de la Rochelle de 1787 à 1787 selon la source Best Guess national product(classification : partner_source)
# Recherche de partenaires de la direction de la Rochelle de 1787 à 1787 selon la source Best Guess national product(classification : partner_orthographic)
# Recherche de partenaires de la direction de la Rochelle de 1787 à 1787 selon la source Best Guess national product(classification : partner_simplification)
# Recherche de partenaires de la direction de la Rochelle de 1787 à 1787 selon la source Best Guess national product(classification : partner_africa)
# Recherche de partenaires de la direction de la Rochelle de 1787 à 1787 selon la source Best Guess national product(classification : partner_grouping)
# Recherche de partenaires de la direction de la Rochelle de 1787 à 1787 selon la source Best Guess national product(classification : partner_obrien)
# Recherche de partenaires de la direction de la Rochelle de 1787 à 1787 selon la source Best Guess national product(classification : partner_sourcename)
# Recherche de partenaires de la direction de la Rochelle de 1787 à 1787 selon la source Best Guess national product(classification : partner_wars)
# Recherche de partenaires de la direction de la Rochelle de 1787 à 1787 selon la source Best Guess national product x partner(classification : partner_source)
# Recherche de partenaires de la direction de la Rochelle de 1787 à 1787 selon la source Best Guess national product x partner(classification : partner_orthographic)
# Recherche de partenaires de la direction de la Rochelle de 1787 à 1787 selon la source Best Guess national product x partner(classification : partner_simplification)
# Recherche de partenaires de la direction de la Rochelle de 1787 à 1787 selon la source Best Guess national product x partner(classification : partner_africa)
# Recherche de partenaires de la direction de la Rochelle de 1787 à 1787 selon la source Best Guess national product x partner(classification : partner_grouping)
# Recherche de partenaires de la direction de la Rochelle de 1787 à 1787 selon la source Best Guess national product x partner(classification : partner_obrien)
# Recherche de partenaires de la direction de la Rochelle de 1787 à 1787 selon la source Best Guess national product x partner(classification : partner_sourcename)
# Recherche de partenaires de la direction de la Rochelle de 1787 à 1787 selon la source Best Guess national product x partner(classification : partner_wars)
# Recherche de partenaires de la direction de la Rochelle de 1787 à 1787 selon la source Compagnie des Indes(classification : partner_source)
# Recherche de partenaires de la direction de la Rochelle de 1787 à 1787 selon la source Compagnie des Indes(classification : partner_orthographic)
# Recherche de partenaires de la direction de la Rochelle de 1787 à 1787 selon la source Compagnie des Indes(classification : partner_simplification)
# Recherche de partenaires de la direction de la Rochelle de 1787 à 1787 selon la source Compagnie des Indes(classification : partner_africa)
# Recherche de partenaires de la direction de la Rochelle de 1787 à 1787 selon la source Compagnie des Indes(classification : partner_grouping)
# Recherche de partenaires de la direction de la Rochelle de 1787 à 1787 selon la source Compagnie des Indes(classification : partner_obrien)
# Recherche de partenaires de la direction de la Rochelle de 1787 à 1787 selon la source Compagnie des Indes(classification : partner_sourcename)
# Recherche de partenaires de la direction de la Rochelle de 1787 à 1787 selon la source Compagnie des Indes(classification : partner_wars)
# Recherche de partenaires de la direction de la Rochelle de 1787 à 1787 selon la source Local(classification : partner_source)
# Recherche de partenaires de la direction de la Rochelle de 1787 à 1787 selon la source Local(classification : partner_orthographic)
# {'partner': 'Possessions suédoises', 'region': "Colonies Françaises de l'Amérique", 'count': 27, 'value': 625378}
# {'partner': "Possessions des États-Unis d'Amérique", 'region': "Colonies Françaises de l'Amérique", 'count': 74, 'value': 16988110}
# {'partner': 'Possessions anglaises', 'region': "Colonies Françaises de l'Amérique", 'count': 67, 'value': 7306915}
# {'partner': 'Possessions espagnoles', 'region': "Colonies Françaises de l'Amérique", 'count': 77, 'value': 5809081}
# {'partner': 'Possessions danoises', 'region': "Colonies Françaises de l'Amérique", 'count': 43, 'value': 408572}
# {'partner': 'Possessions hollandaises', 'region': "Colonies Françaises de l'Amérique", 'count': 73, 'value': 2648895}
# {'partner': 'Possessions portugaises', 'region': "Colonies Françaises de l'Amérique", 'count': 13, 'value': 71000}
# ===
# match
# ===
# Recherche de partenaires de la direction de la Rochelle de 1787 à 1787 selon la source Local(classification : partner_simplification)
# {'partner': 'Colonies suédoises', 'region': "Colonies Françaises de l'Amérique", 'count': 27, 'value': 625378}
# {'partner': "Colonies des États-Unis d'Amérique", 'region': "Colonies Françaises de l'Amérique", 'count': 74, 'value': 16988110}
# {'partner': 'Colonies anglaises', 'region': "Colonies Françaises de l'Amérique", 'count': 67, 'value': 7306915}
# {'partner': 'Colonies espagnoles', 'region': "Colonies Françaises de l'Amérique", 'count': 77, 'value': 5809081}
# {'partner': 'Colonies danoises', 'region': "Colonies Françaises de l'Amérique", 'count': 43, 'value': 408572}
# {'partner': 'Colonies hollandaises', 'region': "Colonies Françaises de l'Amérique", 'count': 73, 'value': 2648895}
# {'partner': 'Colonies portugaises', 'region': "Colonies Françaises de l'Amérique", 'count': 13, 'value': 71000}
# ===
# match
# ===
# Recherche de partenaires de la direction de la Rochelle de 1787 à 1787 selon la source Local(classification : partner_africa)
# {'partner': 'Other outre-mers', 'region': "Colonies Françaises de l'Amérique", 'count': 374, 'value': 33857951}
# ===
# match
# ===
# Recherche de partenaires de la direction de la Rochelle de 1787 à 1787 selon la source Local(classification : partner_grouping)
# {'partner': 'Outre-mers', 'region': "Colonies Françaises de l'Amérique", 'count': 374, 'value': 33857951}
# ===
# match
# ===
# Recherche de partenaires de la direction de la Rochelle de 1787 à 1787 selon la source Local(classification : partner_obrien)
# {'partner': 'Colonies suédoises', 'region': "Colonies Françaises de l'Amérique", 'count': 27, 'value': 625378}
# {'partner': "Colonies des États-Unis d'Amérique", 'region': "Colonies Françaises de l'Amérique", 'count': 74, 'value': 16988110}
# {'partner': 'Colonies anglaises', 'region': "Colonies Françaises de l'Amérique", 'count': 67, 'value': 7306915}
# {'partner': 'Colonies espagnoles', 'region': "Colonies Françaises de l'Amérique", 'count': 77, 'value': 5809081}
# {'partner': 'Colonies danoises', 'region': "Colonies Françaises de l'Amérique", 'count': 43, 'value': 408572}
# {'partner': 'Colonies hollandaises', 'region': "Colonies Françaises de l'Amérique", 'count': 73, 'value': 2648895}
# {'partner': 'Colonies portugaises', 'region': "Colonies Françaises de l'Amérique", 'count': 13, 'value': 71000}
# ===
# match
# ===
# Recherche de partenaires de la direction de la Rochelle de 1787 à 1787 selon la source Local(classification : partner_sourcename)
# {'partner': 'Outre-mers', 'region': "Colonies Françaises de l'Amérique", 'count': 374, 'value': 33857951}
# ===
# match
# ===
# Recherche de partenaires de la direction de la Rochelle de 1787 à 1787 selon la source Local(classification : partner_wars)
# {'partner': 'Suède et ses colonies', 'region': "Colonies Françaises de l'Amérique", 'count': 27, 'value': 625378}
# {'partner': "États-Unis d'Amérique et ses colonies", 'region': "Colonies Françaises de l'Amérique", 'count': 74, 'value': 16988110}
# {'partner': 'Angleterre et ses colonies', 'region': "Colonies Françaises de l'Amérique", 'count': 67, 'value': 7306915}
# {'partner': 'Espagne et ses colonies', 'region': "Colonies Françaises de l'Amérique", 'count': 77, 'value': 5809081}
# {'partner': 'Danemark et ses colonies', 'region': "Colonies Françaises de l'Amérique", 'count': 43, 'value': 408572}
# {'partner': 'Hollande et ses colonies', 'region': "Colonies Françaises de l'Amérique", 'count': 73, 'value': 2648895}
# {'partner': 'Portugal et ses colonies', 'region': "Colonies Françaises de l'Amérique", 'count': 13, 'value': 71000}
# ===
# match
# ===
# Recherche de partenaires de la direction de la Rochelle de 1787 à 1787 selon la source National partenaires manquants(classification : partner_source)
# Recherche de partenaires de la direction de la Rochelle de 1787 à 1787 selon la source National partenaires manquants(classification : partner_orthographic)
# Recherche de partenaires de la direction de la Rochelle de 1787 à 1787 selon la source National partenaires manquants(classification : partner_simplification)
# Recherche de partenaires de la direction de la Rochelle de 1787 à 1787 selon la source National partenaires manquants(classification : partner_africa)
# Recherche de partenaires de la direction de la Rochelle de 1787 à 1787 selon la source National partenaires manquants(classification : partner_grouping)
# Recherche de partenaires de la direction de la Rochelle de 1787 à 1787 selon la source National partenaires manquants(classification : partner_obrien)
# Recherche de partenaires de la direction de la Rochelle de 1787 à 1787 selon la source National partenaires manquants(classification : partner_sourcename)
# Recherche de partenaires de la direction de la Rochelle de 1787 à 1787 selon la source National partenaires manquants(classification : partner_wars)
# Recherche de partenaires de la direction de la Rochelle de 1787 à 1787 selon la source National toutes directions partenaires manquants(classification : partner_source)
# Recherche de partenaires de la direction de la Rochelle de 1787 à 1787 selon la source National toutes directions partenaires manquants(classification : partner_orthographic)
# {'partner': 'Angleterre', 'region': 'Paris', 'count': 7, 'value': 1006855}
# {'partner': 'Angleterre', 'region': 'Montpellier', 'count': 14, 'value': 642000}
# {'partner': 'Angleterre', 'region': 'Flandre', 'count': 115, 'value': 18880000}
# {'partner': 'Angleterre', 'region': 'Amiens', 'count': 52, 'value': 7024000}
# {'partner': 'Angleterre', 'region': 'Marseille', 'count': 33, 'value': 2062000}
# {'partner': 'Angleterre', 'region': 'Rouen', 'count': 74, 'value': 11923000}
# {'partner': 'Angleterre', 'region': 'Caen', 'count': 22, 'value': 755000}
# {'partner': 'Angleterre', 'region': 'Rennes', 'count': 58, 'value': 4146000}
# {'partner': 'Angleterre', 'region': 'La Rochelle', 'count': 16, 'value': 1604000}
# {'partner': 'Angleterre', 'region': 'Bordeaux', 'count': 49, 'value': 12391000}
# {'partner': 'Angleterre', 'region': 'France', 'count': 22, 'value': 1040000}
# {'partner': 'Voitures diverses', 'region': 'Nantes', 'count': 2, 'value': 100800}
# {'partner': 'Saint-Domingue', 'region': 'France', 'count': 51, 'value': 411910}
# {'partner': 'Saint-Domingue', 'region': 'Saint-Malo', 'count': 37, 'value': 327944}
# {'partner': 'Saint-Domingue', 'region': 'La Rochelle', 'count': 23, 'value': 94207}
# {'partner': 'Saint-Domingue', 'region': 'Bayonne', 'count': 32, 'value': 287934}
# {'partner': 'Saint-Domingue', 'region': 'Le Havre', 'count': 134, 'value': 5534840}
# {'partner': 'Saint-Domingue', 'region': 'Nantes', 'count': 163, 'value': 5324674}
# {'partner': 'Saint-Domingue', 'region': 'Bordeaux', 'count': 203, 'value': 29297995}
# {'partner': 'Martinique', 'region': 'France', 'count': 16, 'value': 54153}
# {'partner': 'Martinique', 'region': 'Bayonne', 'count': 27, 'value': 95000}
# {'partner': 'Martinique', 'region': 'Le Havre', 'count': 110, 'value': 2626188}
# {'partner': 'Martinique', 'region': 'Nantes', 'count': 100, 'value': 748925}
# {'partner': 'Martinique', 'region': 'Bordeaux', 'count': 165, 'value': 4981220}
# {'partner': 'Guadeloupe', 'region': 'Saint-Malo', 'count': 14, 'value': 34334}
# {'partner': 'Guadeloupe', 'region': 'Bayonne', 'count': 22, 'value': 55712}
# {'partner': 'Guadeloupe', 'region': 'Le Havre', 'count': 88, 'value': 1168407}
# {'partner': 'Guadeloupe', 'region': 'Nantes', 'count': 106, 'value': 358803}
# {'partner': 'Guadeloupe', 'region': 'Bordeaux', 'count': 171, 'value': 2774051}
# {'partner': 'Cayenne-Guyane', 'region': 'Bordeaux', 'count': 118, 'value': 290016}
# {'partner': 'Sénégal et Guinée', 'region': 'France', 'count': 55, 'value': 725772}
# {'partner': 'Sénégal et Guinée', 'region': 'Saint-Malo', 'count': 40, 'value': 637993}
# {'partner': 'Sénégal et Guinée', 'region': 'La Rochelle', 'count': 68, 'value': 2821563}
# {'partner': 'Sénégal et Guinée', 'region': 'Bayonne', 'count': 10, 'value': 22797}
# {'partner': 'Sénégal et Guinée', 'region': 'Le Havre', 'count': 108, 'value': 5630191}
# {'partner': 'Sénégal et Guinée', 'region': 'Nantes', 'count': 122, 'value': 4875886}
# {'partner': 'Sénégal et Guinée', 'region': 'Bordeaux', 'count': 155, 'value': 2834629}
# {'partner': 'Tobago', 'region': 'Le Havre', 'count': 71, 'value': 159489}
# ===
# match
# ===
# Recherche de partenaires de la direction de la Rochelle de 1787 à 1787 selon la source National toutes directions partenaires manquants(classification : partner_simplification)
# {'partner': 'Angleterre', 'region': 'Paris', 'count': 7, 'value': 1006855}
# {'partner': 'Angleterre', 'region': 'Montpellier', 'count': 14, 'value': 642000}
# {'partner': 'Angleterre', 'region': 'Flandre', 'count': 115, 'value': 18880000}
# {'partner': 'Angleterre', 'region': 'Amiens', 'count': 52, 'value': 7024000}
# {'partner': 'Angleterre', 'region': 'Marseille', 'count': 33, 'value': 2062000}
# {'partner': 'Angleterre', 'region': 'Rouen', 'count': 74, 'value': 11923000}
# {'partner': 'Angleterre', 'region': 'Caen', 'count': 22, 'value': 755000}
# {'partner': 'Angleterre', 'region': 'Rennes', 'count': 58, 'value': 4146000}
# {'partner': 'Angleterre', 'region': 'La Rochelle', 'count': 16, 'value': 1604000}
# {'partner': 'Angleterre', 'region': 'Bordeaux', 'count': 49, 'value': 12391000}
# {'partner': 'Angleterre', 'region': 'France', 'count': 22, 'value': 1040000}
# {'partner': 'Voitures diverses', 'region': 'Nantes', 'count': 2, 'value': 100800}
# {'partner': 'Saint-Domingue', 'region': 'France', 'count': 51, 'value': 411910}
# {'partner': 'Saint-Domingue', 'region': 'Saint-Malo', 'count': 37, 'value': 327944}
# {'partner': 'Saint-Domingue', 'region': 'La Rochelle', 'count': 23, 'value': 94207}
# {'partner': 'Saint-Domingue', 'region': 'Bayonne', 'count': 32, 'value': 287934}
# {'partner': 'Saint-Domingue', 'region': 'Le Havre', 'count': 134, 'value': 5534840}
# {'partner': 'Saint-Domingue', 'region': 'Nantes', 'count': 163, 'value': 5324674}
# {'partner': 'Saint-Domingue', 'region': 'Bordeaux', 'count': 203, 'value': 29297995}
# {'partner': 'Martinique', 'region': 'France', 'count': 16, 'value': 54153}
# {'partner': 'Martinique', 'region': 'Bayonne', 'count': 27, 'value': 95000}
# {'partner': 'Martinique', 'region': 'Le Havre', 'count': 110, 'value': 2626188}
# {'partner': 'Martinique', 'region': 'Nantes', 'count': 100, 'value': 748925}
# {'partner': 'Martinique', 'region': 'Bordeaux', 'count': 165, 'value': 4981220}
# {'partner': 'Guadeloupe', 'region': 'Saint-Malo', 'count': 14, 'value': 34334}
# {'partner': 'Guadeloupe', 'region': 'Bayonne', 'count': 22, 'value': 55712}
# {'partner': 'Guadeloupe', 'region': 'Le Havre', 'count': 88, 'value': 1168407}
# {'partner': 'Guadeloupe', 'region': 'Nantes', 'count': 106, 'value': 358803}
# {'partner': 'Guadeloupe', 'region': 'Bordeaux', 'count': 171, 'value': 2774051}
# {'partner': 'Cayenne et Guyane', 'region': 'Bordeaux', 'count': 118, 'value': 290016}
# {'partner': 'Guinée et Sénégal', 'region': 'France', 'count': 55, 'value': 725772}
# {'partner': 'Guinée et Sénégal', 'region': 'Saint-Malo', 'count': 40, 'value': 637993}
# {'partner': 'Guinée et Sénégal', 'region': 'La Rochelle', 'count': 68, 'value': 2821563}
# {'partner': 'Guinée et Sénégal', 'region': 'Bayonne', 'count': 10, 'value': 22797}
# {'partner': 'Guinée et Sénégal', 'region': 'Le Havre', 'count': 108, 'value': 5630191}
# {'partner': 'Guinée et Sénégal', 'region': 'Nantes', 'count': 122, 'value': 4875886}
# {'partner': 'Guinée et Sénégal', 'region': 'Bordeaux', 'count': 155, 'value': 2834629}
# {'partner': 'Tobago', 'region': 'Le Havre', 'count': 71, 'value': 159489}
# ===
# match
# ===
# Recherche de partenaires de la direction de la Rochelle de 1787 à 1787 selon la source National toutes directions partenaires manquants(classification : partner_africa)
# {'partner': 'Not Outre-mers', 'region': 'Paris', 'count': 7, 'value': 1006855}
# {'partner': 'Not Outre-mers', 'region': 'Montpellier', 'count': 14, 'value': 642000}
# {'partner': 'Not Outre-mers', 'region': 'Flandre', 'count': 115, 'value': 18880000}
# {'partner': 'Not Outre-mers', 'region': 'Amiens', 'count': 52, 'value': 7024000}
# {'partner': 'Not Outre-mers', 'region': 'Marseille', 'count': 33, 'value': 2062000}
# {'partner': 'Not Outre-mers', 'region': 'Rouen', 'count': 74, 'value': 11923000}
# {'partner': 'Not Outre-mers', 'region': 'Caen', 'count': 22, 'value': 755000}
# {'partner': 'Not Outre-mers', 'region': 'Rennes', 'count': 58, 'value': 4146000}
# {'partner': 'Not Outre-mers', 'region': 'La Rochelle', 'count': 16, 'value': 1604000}
# {'partner': 'Not Outre-mers', 'region': 'Bordeaux', 'count': 49, 'value': 12391000}
# {'partner': 'Not Outre-mers', 'region': 'France', 'count': 22, 'value': 1040000}
# {'partner': 'Not Outre-mers', 'region': 'Nantes', 'count': 2, 'value': 100800}
# {'partner': 'Other outre-mers', 'region': 'France', 'count': 67, 'value': 466063}
# {'partner': 'Other outre-mers', 'region': 'Saint-Malo', 'count': 51, 'value': 362278}
# {'partner': 'Other outre-mers', 'region': 'La Rochelle', 'count': 23, 'value': 94207}
# {'partner': 'Other outre-mers', 'region': 'Bayonne', 'count': 81, 'value': 438646}
# {'partner': 'Other outre-mers', 'region': 'Le Havre', 'count': 403, 'value': 9488924}
# {'partner': 'Other outre-mers', 'region': 'Nantes', 'count': 369, 'value': 6432402}
# {'partner': 'Other outre-mers', 'region': 'Bordeaux', 'count': 657, 'value': 37343282}
# {'partner': 'Africa', 'region': 'France', 'count': 55, 'value': 725772}
# {'partner': 'Africa', 'region': 'Saint-Malo', 'count': 40, 'value': 637993}
# {'partner': 'Africa', 'region': 'La Rochelle', 'count': 68, 'value': 2821563}
# {'partner': 'Africa', 'region': 'Bayonne', 'count': 10, 'value': 22797}
# {'partner': 'Africa', 'region': 'Le Havre', 'count': 108, 'value': 5630191}
# {'partner': 'Africa', 'region': 'Nantes', 'count': 122, 'value': 4875886}
# {'partner': 'Africa', 'region': 'Bordeaux', 'count': 155, 'value': 2834629}
# ===
# match
# ===
# Recherche de partenaires de la direction de la Rochelle de 1787 à 1787 selon la source National toutes directions partenaires manquants(classification : partner_grouping)
# {'partner': 'Angleterre', 'region': 'Paris', 'count': 7, 'value': 1006855}
# {'partner': 'Angleterre', 'region': 'Montpellier', 'count': 14, 'value': 642000}
# {'partner': 'Angleterre', 'region': 'Flandre', 'count': 115, 'value': 18880000}
# {'partner': 'Angleterre', 'region': 'Amiens', 'count': 52, 'value': 7024000}
# {'partner': 'Angleterre', 'region': 'Marseille', 'count': 33, 'value': 2062000}
# {'partner': 'Angleterre', 'region': 'Rouen', 'count': 74, 'value': 11923000}
# {'partner': 'Angleterre', 'region': 'Caen', 'count': 22, 'value': 755000}
# {'partner': 'Angleterre', 'region': 'Rennes', 'count': 58, 'value': 4146000}
# {'partner': 'Angleterre', 'region': 'La Rochelle', 'count': 16, 'value': 1604000}
# {'partner': 'Angleterre', 'region': 'Bordeaux', 'count': 49, 'value': 12391000}
# {'partner': 'Angleterre', 'region': 'France', 'count': 22, 'value': 1040000}
# {'partner': 'Divers', 'region': 'Nantes', 'count': 2, 'value': 100800}
# {'partner': 'Amériques', 'region': 'France', 'count': 67, 'value': 466063}
# {'partner': 'Amériques', 'region': 'Saint-Malo', 'count': 51, 'value': 362278}
# {'partner': 'Amériques', 'region': 'La Rochelle', 'count': 23, 'value': 94207}
# {'partner': 'Amériques', 'region': 'Bayonne', 'count': 81, 'value': 438646}
# {'partner': 'Amériques', 'region': 'Le Havre', 'count': 403, 'value': 9488924}
# {'partner': 'Amériques', 'region': 'Nantes', 'count': 369, 'value': 6432402}
# {'partner': 'Amériques', 'region': 'Bordeaux', 'count': 657, 'value': 37343282}
# {'partner': 'Afrique', 'region': 'France', 'count': 55, 'value': 725772}
# {'partner': 'Afrique', 'region': 'Saint-Malo', 'count': 40, 'value': 637993}
# {'partner': 'Afrique', 'region': 'La Rochelle', 'count': 68, 'value': 2821563}
# {'partner': 'Afrique', 'region': 'Bayonne', 'count': 10, 'value': 22797}
# {'partner': 'Afrique', 'region': 'Le Havre', 'count': 108, 'value': 5630191}
# {'partner': 'Afrique', 'region': 'Nantes', 'count': 122, 'value': 4875886}
# ...
# {'partner': "États de l'Empereur", 'region': 'Rouen', 'count': 34, 'value': 652132}
# {'partner': "États de l'Empereur", 'region': 'Nantes', 'count': 1, 'value': 6050}
# {'partner': "États de l'Empereur", 'region': 'Flandre', 'count': 1358, 'value': 22796270}
# {'partner': "États de l'Empereur", 'region': 'Valenciennes', 'count': 547, 'value': 8336496}
# {'partner': 'France', 'region': 'Rouen', 'count': 240, 'value': 7817223}
# {'partner': 'France', 'region': 'Nantes', 'count': 3, 'value': 40584}
# {'partner': 'France', 'region': 'Flandre', 'count': 557, 'value': 4398723.25}
# {'partner': 'France', 'region': 'Valenciennes', 'count': 4, 'value': 6166}
# {'partner': 'Duché de Bouillon', 'region': 'Charleville', 'count': 106, 'value': 412029.5581359863}
# {'partner': 'Prusse', 'region': 'Charleville', 'count': 3, 'value': 21801}
# {'partner': 'Naples', 'region': 'Grenoble', 'count': 48, 'value': 135688}
# {'partner': 'Naples', 'region': 'Lyon', 'count': 1, 'value': 1453.5}
# {'partner': 'Milanais, Toscane et Lucques', 'region': 'Grenoble', 'count': 78, 'value': 706033.125}
# {'partner': 'France', 'region': 'Lyon', 'count': 6, 'value': 126810}
# {'partner': 'Royaume de Piemont et Sardaigne', 'region': 'Lyon', 'count': 64, 'value': 256662.85000610352}
# {'partner': 'Milanais, Toscane et Lucques', 'region': 'Narbonne', 'count': 1, 'value': 21674.720703125}
# {'partner': 'Pologne', 'region': 'Lorient', 'count': 2, 'value': 4812}
# {'partner': 'Naples', 'region': 'France', 'count': 27, 'value': 59140}
# {'partner': 'Naples', 'region': 'Marseille', 'count': 183, 'value': 28942068.969955444}
# {'partner': 'Milanais, Toscane et Lucques', 'region': 'Montpellier', 'count': 17, 'value': 35562.47514343262}
# {'partner': 'Milanais, Toscane et Lucques', 'region': 'Marseille', 'count': 234, 'value': 6663238.495849609}
# {'partner': 'Villes hanséatiques', 'region': 'Châlons', 'count': 21, 'value': 177407}
# {'partner': 'Villes hanséatiques', 'region': 'La Rochelle', 'count': 40, 'value': 1015274.2886047363}
# {'partner': "États-Unis d'Amérique et ses colonies", 'region': 'La Rochelle', 'count': 12, 'value': 101461.06616210938}
# {'partner': 'Allemagne', 'region': 'Valenciennes', 'count': 300, 'value': 1272065}
# {'partner': 'Allemagne', 'region': 'France', 'count': 31, 'value': 52540}
# {'partner': 'Danemark et ses colonies', 'region': 'Châlons', 'count': 10, 'value': 15839.5}
# {'partner': 'Nord', 'region': 'France', 'count': 2, 'value': 9150}
# {'partner': 'Nord', 'region': 'Châlons', 'count': 13, 'value': 102924.00006103516}
# {'partner': 'Levant', 'region': 'Châlons', 'count': 2, 'value': 1630.75}
# {'partner': "États de l'Empereur", 'region': 'La Rochelle', 'count': 12, 'value': 414060.9443283081}
# {'partner': 'Levant', 'region': 'Montpellier', 'count': 4, 'value': 46891.50001525879}
# {'partner': "États de l'Empereur", 'region': 'Montpellier', 'count': 37, 'value': 1240118.9012451172}
# {'partner': "États de l'Empereur", 'region': 'Soisson', 'count': 16, 'value': 59106}
# {'partner': "États de l'Empereur", 'region': 'Saint-Quentin', 'count': 13, 'value': 11615}
# {'partner': 'France', 'region': 'Narbonne', 'count': 123, 'value': 576119.2657165527}
# {'partner': 'Royaume de Piemont et Sardaigne', 'region': 'Montpellier', 'count': 69, 'value': 870373.4629211426}
# {'partner': 'Royaume de Piemont et Sardaigne', 'region': 'Grenoble', 'count': 720, 'value': 28658948.003982544}
# {'partner': 'Royaume de Piemont et Sardaigne', 'region': 'Bordeaux', 'count': 1, 'value': 100}
# {'partner': 'Royaume de Piemont et Sardaigne', 'region': 'Toulon', 'count': 384, 'value': 2295463.487136841}
# {'partner': 'Royaume de Piemont et Sardaigne', 'region': 'Charleville', 'count': 1, 'value': 773.6000366210938}
# {'partner': 'Royaume de Piemont et Sardaigne', 'region': 'France', 'count': 13, 'value': 22343}
# {'partner': 'États ecclésiastiques', 'region': 'Toulon', 'count': 14, 'value': 35320.8359375}
# {'partner': 'Milanais, Toscane et Lucques', 'region': 'Toulon', 'count': 16, 'value': 584217.208984375}
# {'partner': 'Divers', 'region': 'Marseille', 'count': 77, 'value': 25910432.106788635}
# {'partner': 'Divers', 'region': 'Toulon', 'count': 55, 'value': 181544.6305847168}
# {'partner': 'Villes hanséatiques', 'region': 'Montpellier', 'count': 32, 'value': 806026.2456359863}
# {'partner': 'Villes hanséatiques', 'region': 'Charleville', 'count': 4, 'value': 95032.8984375}
# {'partner': 'Villes hanséatiques', 'region': 'Bayonne', 'count': 12, 'value': 768579}
# {'partner': 'Villes hanséatiques', 'region': 'Amiens', 'count': 2, 'value': 2347}
# {'partner': 'Villes hanséatiques', 'region': 'Saint-Malo', 'count': 8, 'value': 154458.796875}
# {'partner': 'Villes hanséatiques', 'region': 'Langres', 'count': 4, 'value': 1654.000015258789}
# {'partner': 'Villes hanséatiques', 'region': 'Lorient', 'count': 17, 'value': 731996}
# {'partner': 'Villes hanséatiques', 'region': 'Toulon', 'count': 1, 'value': 25200}
# {'partner': 'Colonies françaises', 'region': 'France', 'count': 218, 'value': 990760}
# {'partner': 'Colonies françaises', 'region': 'Saint-Malo', 'count': 91, 'value': 853409}
# {'partner': 'Colonies françaises', 'region': 'Bayonne', 'count': 92, 'value': 500164}
# {'partner': 'Colonies françaises', 'region': 'Dunkerque', 'count': 288, 'value': 1411503}
# {'partner': 'Colonies françaises', 'region': 'Marseille', 'count': 922, 'value': 14961701}
# {'partner': 'Colonies françaises', 'region': 'Le Havre', 'count': 771, 'value': 10337587}
# {'partner': 'Colonies françaises', 'region': 'Nantes', 'count': 792, 'value': 13288665}
# {'partner': 'Colonies françaises', 'region': 'Bordeaux', 'count': 1425, 'value': 33971869}
# {'partner': 'Colonies françaises', 'region': 'Rouen', 'count': 5, 'value': 2517631}
# {'partner': 'Colonies françaises', 'region': 'Lorient', 'count': 1, 'value': 2370}
# {'partner': 'Divers', 'region': 'France', 'count': 3, 'value': 607756}
# {'partner': 'Divers', 'region': 'Flandre', 'count': 7, 'value': 4560525}
# {'partner': 'Divers', 'region': 'Rouen', 'count': 18, 'value': 23589876}
# {'partner': 'Divers', 'region': 'Saint-Malo', 'count': 4, 'value': 439241}
# {'partner': 'Divers', 'region': 'Nantes', 'count': 8, 'value': 26188654}
# {'partner': 'Divers', 'region': 'Lorient', 'count': 1, 'value': 1872}
# {'partner': 'Divers', 'region': 'La Rochelle', 'count': 8, 'value': 5136098}
# {'partner': 'Divers', 'region': 'Bordeaux', 'count': 9, 'value': 74611017}
# {'partner': "États de l'Empereur", 'region': 'Langres', 'count': 2, 'value': 1900}
# {'partner': 'États du roi', 'region': 'Saint-Malo', 'count': 1, 'value': 57901.6015625}
# {'partner': 'Duché de Bouillon', 'region': 'Valenciennes', 'count': 2, 'value': 2628}
# {'partner': 'Allemagne', 'region': 'Rouen', 'count': 4, 'value': 285172}
# {'partner': 'Allemagne', 'region': 'Flandre', 'count': 15, 'value': 88720}
# {'partner': 'Milanais, Toscane et Lucques', 'region': 'Flandre', 'count': 15, 'value': 254665}
# {'partner': 'Genève et Suisse', 'region': 'France', 'count': 10, 'value': 84364}
# {'partner': 'Espagne et ses colonies', 'region': 'France', 'count': 16, 'value': 28276}
# {'partner': 'Milanais, Toscane et Lucques', 'region': 'France', 'count': 1, 'value': 320}
# {'partner': 'Levant', 'region': 'France', 'count': 6, 'value': 10090}
# {'partner': "États de l'Empereur", 'region': 'France', 'count': 1, 'value': 576}
# {'partner': 'Flandre', 'region': 'Le Havre', 'count': 1, 'value': 39000}
# {'partner': 'Milanais, Toscane et Lucques', 'region': 'Rouen', 'count': 3, 'value': 35230}
# {'partner': 'Gênes', 'region': 'Rouen', 'count': 9, 'value': 2219556}
# {'partner': 'Gênes', 'region': 'Flandre', 'count': 32, 'value': 825169}
# {'partner': 'Venise', 'region': 'Flandre', 'count': 5, 'value': 113330}
# {'partner': 'Royaume de Piemont et Sardaigne', 'region': 'Rouen', 'count': 4, 'value': 575943}
# {'partner': 'Royaume de Piemont et Sardaigne', 'region': 'Flandre', 'count': 5, 'value': 66534}
# {'partner': 'États ecclésiastiques', 'region': 'Rouen', 'count': 12, 'value': 114969}
# {'partner': 'États ecclésiastiques', 'region': 'Flandre', 'count': 1, 'value': 300}
# {'partner': 'Genève et Suisse', 'region': 'Narbonne', 'count': 4, 'value': 8741.81591796875}
# {'partner': 'États ecclésiastiques', 'region': 'Narbonne', 'count': 1, 'value': 1031.904052734375}
# {'partner': 'Gênes', 'region': 'Grenoble', 'count': 28, 'value': 92551.25}
# {'partner': "États de l'Empereur", 'region': 'Châlons', 'count': 70, 'value': 623470.6785888672}
# {'partner': "États de l'Empereur", 'region': 'Grenoble', 'count': 14, 'value': 17014}
# {'partner': "États de l'Empereur", 'region': 'Toulon', 'count': 2, 'value': 18617.397216796875}
# {'partner': 'Genève et Suisse', 'region': 'Rouen', 'count': 2, 'value': 586}
# {'partner': 'Genève et Suisse', 'region': 'Flandre', 'count': 4, 'value': 4287}
# {'partner': 'Pologne', 'region': 'Rouen', 'count': 15, 'value': 35515}
# {'partner': 'Pologne', 'region': 'Flandre', 'count': 1, 'value': 1500}
# {'partner': "États de l'Empereur", 'region': 'Saint-Malo', 'count': 2, 'value': 39505.25}
# ===
# match
# ===
# Recherche de partenaires de la direction de la Rochelle de 1789 à 1789 selon la source National toutes directions sans produits(classification : partner_source)
# Recherche de partenaires de la direction de la Rochelle de 1789 à 1789 selon la source National toutes directions sans produits(classification : partner_orthographic)
# Recherche de partenaires de la direction de la Rochelle de 1789 à 1789 selon la source National toutes directions sans produits(classification : partner_simplification)
# Recherche de partenaires de la direction de la Rochelle de 1789 à 1789 selon la source National toutes directions sans produits(classification : partner_africa)
# Recherche de partenaires de la direction de la Rochelle de 1789 à 1789 selon la source National toutes directions sans produits(classification : partner_grouping)
# Recherche de partenaires de la direction de la Rochelle de 1789 à 1789 selon la source National toutes directions sans produits(classification : partner_obrien)
# Recherche de partenaires de la direction de la Rochelle de 1789 à 1789 selon la source National toutes directions sans produits(classification : partner_sourcename)
# Recherche de partenaires de la direction de la Rochelle de 1789 à 1789 selon la source National toutes directions sans produits(classification : partner_wars)
# Recherche de partenaires de la direction de la Rochelle de 1789 à 1789 selon la source National toutes directions tous partenaires(classification : partner_source)
# Recherche de partenaires de la direction de la Rochelle de 1789 à 1789 selon la source National toutes directions tous partenaires(classification : partner_orthographic)
# Recherche de partenaires de la direction de la Rochelle de 1789 à 1789 selon la source National toutes directions tous partenaires(classification : partner_simplification)
# Recherche de partenaires de la direction de la Rochelle de 1789 à 1789 selon la source National toutes directions tous partenaires(classification : partner_africa)
# Recherche de partenaires de la direction de la Rochelle de 1789 à 1789 selon la source National toutes directions tous partenaires(classification : partner_grouping)
# Recherche de partenaires de la direction de la Rochelle de 1789 à 1789 selon la source National toutes directions tous partenaires(classification : partner_obrien)
# Recherche de partenaires de la direction de la Rochelle de 1789 à 1789 selon la source National toutes directions tous partenaires(classification : partner_sourcename)
# Recherche de partenaires de la direction de la Rochelle de 1789 à 1789 selon la source National toutes directions tous partenaires(classification : partner_wars)
# Recherche de partenaires de la direction de la Rochelle de 1789 à 1789 selon la source Objet Général(classification : partner_source)
# Recherche de partenaires de la direction de la Rochelle de 1789 à 1789 selon la source Objet Général(classification : partner_orthographic)
# Recherche de partenaires de la direction de la Rochelle de 1789 à 1789 selon la source Objet Général(classification : partner_simplification)
# Recherche de partenaires de la direction de la Rochelle de 1789 à 1789 selon la source Objet Général(classification : partner_africa)
# Recherche de partenaires de la direction de la Rochelle de 1789 à 1789 selon la source Objet Général(classification : partner_grouping)
# Recherche de partenaires de la direction de la Rochelle de 1789 à 1789 selon la source Objet Général(classification : partner_obrien)
# Recherche de partenaires de la direction de la Rochelle de 1789 à 1789 selon la source Objet Général(classification : partner_sourcename)
# Recherche de partenaires de la direction de la Rochelle de 1789 à 1789 selon la source Objet Général(classification : partner_wars)
# Recherche de partenaires de la direction de la Rochelle de 1789 à 1789 selon la source Résumé(classification : partner_source)
# Recherche de partenaires de la direction de la Rochelle de 1789 à 1789 selon la source Résumé(classification : partner_orthographic)
# Recherche de partenaires de la direction de la Rochelle de 1789 à 1789 selon la source Résumé(classification : partner_simplification)
# Recherche de partenaires de la direction de la Rochelle de 1789 à 1789 selon la source Résumé(classification : partner_africa)
# Recherche de partenaires de la direction de la Rochelle de 1789 à 1789 selon la source Résumé(classification : partner_grouping)
# Recherche de partenaires de la direction de la Rochelle de 1789 à 1789 selon la source Résumé(classification : partner_obrien)
# Recherche de partenaires de la direction de la Rochelle de 1789 à 1789 selon la source Résumé(classification : partner_sourcename)
# Recherche de partenaires de la direction de la Rochelle de 1789 à 1789 selon la source Résumé(classification : partner_wars)
# Recherche de partenaires de la direction de la Rochelle de 1789 à 1789 selon la source Tableau Général(classification : partner_source)
# Recherche de partenaires de la direction de la Rochelle de 1789 à 1789 selon la source Tableau Général(classification : partner_orthographic)
# Recherche de partenaires de la direction de la Rochelle de 1789 à 1789 selon la source Tableau Général(classification : partner_simplification)
# Recherche de partenaires de la direction de la Rochelle de 1789 à 1789 selon la source Tableau Général(classification : partner_africa)
# Recherche de partenaires de la direction de la Rochelle de 1789 à 1789 selon la source Tableau Général(classification : partner_grouping)
# Recherche de partenaires de la direction de la Rochelle de 1789 à 1789 selon la source Tableau Général(classification : partner_obrien)
# Recherche de partenaires de la direction de la Rochelle de 1789 à 1789 selon la source Tableau Général(classification : partner_sourcename)
# Recherche de partenaires de la direction de la Rochelle de 1789 à 1789 selon la source Tableau Général(classification : partner_wars)
# Recherche de partenaires de la direction de la Rochelle de 1789 à 1789 selon la source Tableau des quantités(classification : partner_source)
# Recherche de partenaires de la direction de la Rochelle de 1789 à 1789 selon la source Tableau des quantités(classification : partner_orthographic)
# Recherche de partenaires de la direction de la Rochelle de 1789 à 1789 selon la source Tableau des quantités(classification : partner_simplification)
# Recherche de partenaires de la direction de la Rochelle de 1789 à 1789 selon la source Tableau des quantités(classification : partner_africa)
# Recherche de partenaires de la direction de la Rochelle de 1789 à 1789 selon la source Tableau des quantités(classification : partner_grouping)
# Recherche de partenaires de la direction de la Rochelle de 1789 à 1789 selon la source Tableau des quantités(classification : partner_obrien)
# Recherche de partenaires de la direction de la Rochelle de 1789 à 1789 selon la source Tableau des quantités(classification : partner_sourcename)
# Recherche de partenaires de la direction de la Rochelle de 1789 à 1789 selon la source Tableau des quantités(classification : partner_wars)

# %%
# formattage des résultats
results_filtered = filter(lambda r : len(r["flux"]) > 0, results)

print("| année | source | classification | nombre de flux | détail des flux |")
print("|---|---|---|---|---|")
for item in list(results_filtered):
    print('| ' + str(item["year"]) + ' | ' + item["source"] + ' | ' + item["classification"] + ' | ' + str(len(item["flux"])) + '|' + ', '.join(list(map(lambda i : i["partner"] + "(" + str(i["count"]) + ")", item["flux"]))) + ' |')
    # print('| ' + str(item["year"]) + ' | ' + item["source"] + " | " + item["classification"] + len(item["flux"]) ± " | |")
# Out:
# | année | source | classification | nombre de flux | détail des flux |
# |---|---|---|---|---|

# %% [markdown]
# ### Flux disponibles en provenance de la Rochelle (1787-1789)
#
# | année | source | classification | nombre de partenaires | détail des flux |
# |---|---|---|---|---|
# | 1787 | National toutes directions partenaires manquants | partner_orthographic | 3|Angleterre(16), Sénégal et Guinée(68), Saint-Domingue(23) |
# | 1787 | National toutes directions partenaires manquants | partner_simplification | 3|Angleterre(16), Guinée et Sénégal(68), Saint-Domingue(23) |
# | 1787 | National toutes directions partenaires manquants | partner_africa | 3|Not Outre-mers(16), Africa(68), Other outre-mers(23) |
# | 1787 | National toutes directions partenaires manquants | partner_grouping | 2|Angleterre(16), Outre-mers(91) |
# | 1787 | National toutes directions partenaires manquants | partner_obrien | 3|Angleterre(16), Guinée et Sénégal(68), Saint-Domingue(23) |
# | 1787 | National toutes directions partenaires manquants | partner_sourcename | 3|Angleterre(16), Guinée(68), Colonies(23) |
# | 1787 | National toutes directions partenaires manquants | partner_wars | 2|Angleterre et ses colonies(16), Colonies françaises(91) |
# | 1788 | National toutes directions partenaires manquants | partner_orthographic | 3|Saint-Domingue(74), Colonies françaises de l'Amérique(24), Sénégal et Guinée(1) |
# | 1788 | National toutes directions partenaires manquants | partner_simplification | 3|Saint-Domingue(74), Colonies françaises d'Amérique(24), Guinée et Sénégal(1) |
# | 1788 | National toutes directions partenaires manquants | partner_africa | 2|Other outre-mers(98), Africa(1) |
# | 1788 | National toutes directions partenaires manquants | partner_grouping | 1|Outre-mers(99) |
# | 1788 | National toutes directions partenaires manquants | partner_obrien | 3|Saint-Domingue(74), Colonies françaises d'Amérique(24), Guinée et Sénégal(1) |
# | 1788 | National toutes directions partenaires manquants | partner_sourcename | 2|Colonies(98), Guinée(1) |
# | 1788 | National toutes directions partenaires manquants | partner_wars | 1|Colonies françaises(99) |
# | 1789 | National toutes directions partenaires manquants | partner_orthographic | 25|Sénégal(149), Saint-Domingue(45), Étranger(8), Îles françaises de l'Amérique(27), Sénégal et Guinée(1), Petites Îles(356), Bayonne(16), Lorient(22), Espagne(19), Angleterre(84), Dunkerque(33), Portugal(2), Hollande(108), Quatre villes hanséatiques(40), États de l'Empereur(7), Danemark(21), Prusse(19), Amérique(10), États-Unis(2), Saint-Jean de Luz(1), Russie(14), Suède(9), Marseille(60), Allemagne(3), Empereur(5) |
# | 1789 | National toutes directions partenaires manquants | partner_simplification | 23|Sénégal(149), Saint-Domingue(45), Monde hors colonies(8), Îles françaises de l'Amérique(27), Guinée et Sénégal(1), Petites Îles(356), Bayonne(16), Lorient(22), Espagne(19), Angleterre(84), Dunkerque(33), Portugal(2), Hollande(108), Villes hanséatiques(40), États de l'Empereur(12), Danemark(21), Prusse(19), États-Unis d'Amérique(12), Saint-Jean de Luz(1), Russie(14), Suède(9), Marseille(60), Allemagne(3) |
# | 1789 | National toutes directions partenaires manquants | partner_africa | 3|Africa(150), Other outre-mers(72), Not Outre-mers(839) |
# | 1789 | National toutes directions partenaires manquants | partner_grouping | 11|Outre-mers(222), Monde(8), France(488), Espagne(19), Angleterre(84), Portugal(2), Hollande(108), Nord(103), Flandre et autres états de l'Empereur(12), États-Unis d'Amérique(12), Allemagne(3) |
# | 1789 | National toutes directions partenaires manquants | partner_obrien | 21|Sénégal(149), Saint-Domingue(45), Îles françaises de l'Amérique(27), Guinée et Sénégal(1), Petites Îles(356), Bayonne(16), Lorient(22), Espagne et ses colonies(19), Angleterre(84), Dunkerque(33), Portugal(2), Hollande(108), Villes hanséatiques(40), États de l'Empereur(12), Danemark(21), Prusse(19), États-Unis d'Amérique(12), Russie(14), Suède et ses colonies(9), Marseille(60), Allemagne(3) |
# | 1789 | National toutes directions partenaires manquants | partner_sourcename | 17|Outre-mers(149), Colonies(72), Monde(8), Guinée(1), France(488), Espagne(19), Angleterre(84), Portugal(2), Hollande(108), Villes hanséatiques(40), Flandres(12), Danemark(21), Prusse(19), États-Unis d'Amérique(12), Russie(14), Suède(9), Allemagne(3) |
# | 1789 | National toutes directions partenaires manquants | partner_wars | 16|Colonies françaises(195), Divers(8), Îles(383), France(131), Espagne et ses colonies(20), Angleterre et ses colonies(84), Portugal et ses colonies(2), Hollande et ses colonies(108), Villes hanséatiques(40), États de l'Empereur(12), Danemark et ses colonies(21), Prusse(19), États-Unis d'Amérique et ses colonies(12), Nord(14), Suède et ses colonies(9), Allemagne(3) |

# %% [markdown]
# # Vers le croisement
#
# ## Remarques sur le mapping
#
# Le mapping géographique ne me semble pas trop compliqué : on filtre sur la direction de la Rochelle côté PORTIC ?
#
# C'est le mapping des produits qui peut être plus complexe.
#
# Les méthodes d'agrégation des produits sont dynamiques dans TOFLIT18, statiques dans PORTIC. Besoin d'une classification à la toflit sur les marchandises de PORTIC ?

# %%
from vega import VegaLite
import pandas as pd

# %%
"""VegaLite({
    "mark": "point",
    "encoding": {
        "x": {
            "type": "quantitative",
            "field": "année"
        },
        "y": {
            "type": "nominal",
            "field": "source"
        }
    }
}, results_filtered)

test = [
    {
        "age": 1,
        "lieu": 5
    },
    {
        "age": 2,
        "lieu": 3
    },
    {
        "age": 5,
        "lieu": 5
    },
    {
        "age": 1,
        "lieu": 1
    },
    {
        "age": 5,
        "lieu": 2
    }
]
VegaLite({
    "mark": "point",
    "encoding": {
        "x": {
            "type": "quantitative",
            "field": "age"
        },
        "y": {
            "type": "quantitative",
            "field": "lieu"
        }
    }
}, pd.DataFrame(test))
"""
# Out:
# 'VegaLite({\n    "mark": "point",\n    "encoding": {\n        "x": {\n            "type": "quantitative",\n            "field": "année"\n        },\n        "y": {\n            "type": "nominal",\n            "field": "source"\n        }\n    }\n}, results_filtered)\n\ntest = [\n    {\n        "age": 1,\n        "lieu": 5\n    },\n    {\n        "age": 2,\n        "lieu": 3\n    },\n    {\n        "age": 5,\n        "lieu": 5\n    },\n    {\n        "age": 1,\n        "lieu": 1\n    },\n    {\n        "age": 5,\n        "lieu": 2\n    }\n]\nVegaLite({\n    "mark": "point",\n    "encoding": {\n        "x": {\n            "type": "quantitative",\n            "field": "age"\n        },\n        "y": {\n            "type": "quantitative",\n            "field": "lieu"\n        }\n    }\n}, pd.DataFrame(test))\n'

# %%
df = pd.DataFrame(results)
df.head()
# Out:
#    year          classification                                       source  \
# 0  1787    partner_orthographic  Best Guess customs region product x partner
# 1  1787  partner_simplification  Best Guess customs region product x partner
# 2  1787          partner_africa  Best Guess customs region product x partner
# 3  1787        partner_grouping  Best Guess customs region product x partner
# 4  1787          partner_obrien  Best Guess customs region product x partner
#
#   flux
# 0   []
# 1   []
# 2   []
# 3   []
# 4   []
