# %%
# bootstrapping du client
from lib.client import Api
import json

client = Api()

# %% [markdown]
# # Documentation de l'API de TOFLIT et implémentation dans le client

# %%
print(help(client.toflit.get_directions))
"""
resp = client.toflit.get_network('partner_grouping', params={
	"dateMax": "1750",
	"dateMin": "1750",
	"kind": "total",
	"sourceType": "National best guess"
})
"""
resp = client.toflit.get_classification_groups(classification='product_simplification')
print(json.dumps(resp, indent=2))
# Out:
# Help on method get_directions in module lib.toflit:
#
# get_directions(params=None) method of lib.toflit.Toflit instance
#     Synopsis : récupère les directions de la base
#
# None
# -----------FINAL QUERY-----------
# GET http://toflit18.medialab.sciences-po.fr/api/classification/product_simplification/groups/
#
#
# None
# [
#   {
#     "id": "???~product_simplification",
#     "name": "???"
#   },
#   {
#     "id": "???_blanc~product_simplification",
#     "name": "??? blanc"
#   },
#   {
#     "id": "???_brun~product_simplification",
#     "name": "??? brun"
#   },
#   {
#     "id": "???_d'Anjou_et_de_Touraine~product_simplification",
#     "name": "??? d'Anjou et de Touraine"
#   },
#   {
#     "id": "???_d'argent~product_simplification",
#     "name": "??? d'argent"
#   },
#   {
#     "id": "???_d'une_valeur_moindre_de_deux_mille_francs_chacun~product_simplification",
#     "name": "??? d'une valeur moindre de deux mille francs chacun"
#   },
#   {
#     "id": "???_de_boutard~product_simplification",
#     "name": "??? de boutard"
#   },
#   {
#     "id": "???_de_fer~product_simplification",
#     "name": "??? de fer"
#   },
#   {
#     "id": "???_de_morue~product_simplification",
#     "name": "??? de morue"
#   },
#   {
#     "id": "???_de_nacre_de_perle~product_simplification",
#     "name": "??? de nacre de perle"
#   },
#   {
#     "id": "???_des_ci-devant_provinces_d'Alsace~product_simplification",
#     "name": "??? des ci-devant provinces d'Alsace"
#   },
#   {
#     "id": "???_des_ci-devant_provinces_de_Bourgogne~product_simplification",
#     "name": "??? des ci-devant provinces de Bourgogne"
#   },
#   {
#     "id": "???_des_ci-devant_provinces_de_Provence~product_simplification",
#     "name": "??? des ci-devant provinces de Provence"
#   },
#   {
#     "id": "???_des_ci-devant_provinces_du_Languedoc~product_simplification",
#     "name": "??? des ci-devant provinces du Languedoc"
#   },
#   {
#     "id": "???_diverses~product_simplification",
#     "name": "??? diverses"
#   },
#   {
#     "id": "???_fer~product_simplification",
#     "name": "??? fer"
#   },
#   {
#     "id": "???_forts_de_fer~product_simplification",
#     "name": "??? forts de fer"
#   },
#   {
#     "id": "???_gras~product_simplification",
#     "name": "??? gras"
#   },
#   {
#     "id": "???_particuli\u00e8rement_en_chevaux~product_simplification",
#     "name": "??? particuli\u00e8rement en chevaux"
#   },
#   {
#     "id": "???_pieds~product_simplification",
#     "name": "??? pieds"
#   },
#   {
#     "id": "???_pruneaux~product_simplification",
#     "name": "??? pruneaux"
#   },
#   {
#     "id": "???_raisins_secs~product_simplification",
#     "name": "??? raisins secs"
#   },
#   {
#     "id": "???sse~product_simplification",
#     "name": "???sse"
#   },
#   {
#     "id": "?ufs~product_simplification",
#     "name": "?ufs"
#   },
#   {
#     "id": "abassis~product_simplification",
#     "name": "abassis"
#   },
#   {
#     "id": "abats~product_simplification",
#     "name": "abats"
#   },
#   {
#     "id": "abattis_de_morue~product_simplification",
#     "name": "abattis de morue"
#   },
#   {
#     "id": "abricots_confits~product_simplification",
#     "name": "abricots confits"
#   },
#   {
#     "id": "absinthe~product_simplification",
#     "name": "absinthe"
#   },
#   {
#     "id": "acacia~product_simplification",
#     "name": "acacia"
#   },
#   {
#     "id": "acacia_germanica~product_simplification",
#     "name": "acacia germanica"
#   },
#   {
#     "id": "acacia_vera~product_simplification",
#     "name": "acacia vera"
#   },
#   {
#     "id": "acajou~product_simplification",
#     "name": "acajou"
#   },
#   {
#     "id": "achia~product_simplification",
#     "name": "achia"
#   },
#   {
#     "id": "acide_ars\u00e9nieux~product_simplification",
#     "name": "acide ars\u00e9nieux"
#   },
#   {
#     "id": "acide_benzo\u00efque~product_simplification",
#     "name": "acide benzo\u00efque"
#   },
#   {
#     "id": "acide_benzo\u00efque_et_phosphorique~product_simplification",
#     "name": "acide benzo\u00efque et phosphorique"
#   },
#   {
#     "id": "acide_borique~product_simplification",
#     "name": "acide borique"
#   },
#   {
#     "id": "acide_borique_et_benzo\u00efque~product_simplification",
#     "name": "acide borique et benzo\u00efque"
#   },
#   {
#     "id": "acide_citrique~product_simplification",
#     "name": "acide citrique"
#   },
#   {
#     "id": "acide_citrique_et_muriatique_et_phosphorique~product_simplification",
#     "name": "acide citrique et muriatique et phosphorique"
#   },
#   {
#     "id": "acide_citrique_et_oxalique_et_tartrique~product_simplification",
#     "name": "acide citrique et oxalique et tartrique"
#   },
#   {
#     "id": "acide_de_potasse_cr\u00e8me_de_tartre~product_simplification",
#     "name": "acide de potasse cr\u00e8me de tartre"
#   },
#   {
#     "id": "acide_de_potasse_lie_de_vin_dess\u00e9ch\u00e9_et_liquide~product_simplification",
#     "name": "acide de potasse lie de vin dess\u00e9ch\u00e9 et liquide"
#   },
#   {
#     "id": "acide_de_potasse_lie_de_vin_dess\u00e9ch\u00e9e~product_simplification",
#     "name": "acide de potasse lie de vin dess\u00e9ch\u00e9e"
#   },
#   {
#     "id": "acide_de_potasse_lie_de_vin_liquide~product_simplification",
#     "name": "acide de potasse lie de vin liquide"
#   },
#   {
#     "id": "acide_de_potasse_tartre_brut_impur~product_simplification",
#     "name": "acide de potasse tartre brut impur"
#   },
#   {
#     "id": "acide_muriatique~product_simplification",
#     "name": "acide muriatique"
#   },
#   {
#     "id": "acide_muriatique_et_nitrique_et_phosphorique~product_simplification",
#     "name": "acide muriatique et nitrique et phosphorique"
#   },
#   {
#     "id": "acide_muriatique_et_nitro-muriatique~product_simplification",
#     "name": "acide muriatique et nitro-muriatique"
#   },
#   {
#     "id": "acide_nitrique~product_simplification",
#     "name": "acide nitrique"
#   },
#   {
#     "id": "acide_oxalique~product_simplification",
#     "name": "acide oxalique"
#   },
#   {
#     "id": "acide_phosphorique~product_simplification",
#     "name": "acide phosphorique"
#   },
#   {
#     "id": "acide_succinique~product_simplification",
#     "name": "acide succinique"
#   },
#   {
#     "id": "acide_tartrique~product_simplification",
#     "name": "acide tartrique"
#   },
#   {
#     "id": "acide_vitriolique~product_simplification",
#     "name": "acide vitriolique"
#   },
#   {
#     "id": "acide_vitriolique_et_huile_de_vitriol~product_simplification",
#     "name": "acide vitriolique et huile de vitriol"
#   },
#   {
#     "id": "acier~product_simplification",
#     "name": "acier"
#   },
#   {
#     "id": "acier_battu_forg\u00e9_ou_lamin\u00e9~product_simplification",
#     "name": "acier battu forg\u00e9 ou lamin\u00e9"
#   },
#   {
#     "id": "acier_brun~product_simplification",
#     "name": "acier brun"
#   },
#   {
#     "id": "acier_brut~product_simplification",
#     "name": "acier brut"
#   },
#   {
#     "id": "acier_commun~product_simplification",
#     "name": "acier commun"
#   },
#   {
#     "id": "acier_en_barres~product_simplification",
#     "name": "acier en barres"
#   },
#   {
#     "id": "acier_en_bottes_pour_la_Compagnie_des_Indes~product_simplification",
#     "name": "acier en bottes pour la Compagnie des Indes"
#   },
#   {
#     "id": "acier_et_clous~product_simplification",
#     "name": "acier et clous"
#   },
#   {
#     "id": "acier_et_fer~product_simplification",
#     "name": "acier et fer"
#   },
#   {
#     "id": "acier_fondu_en_carreaux_ou_en_t\u00f4le~product_simplification",
#     "name": "acier fondu en carreaux ou en t\u00f4le"
#   },
#   {
#     "id": "acier_fondu_forg\u00e9~product_simplification",
#     "name": "acier fondu forg\u00e9"
#   },
#   {
#     "id": "acier_forg\u00e9~product_simplification",
#     "name": "acier forg\u00e9"
#   },
#   {
#     "id": "acons~product_simplification",
#     "name": "acons"
#   },
#   {
#     "id": "acons_d\u00e9mont\u00e9s~product_simplification",
#     "name": "acons d\u00e9mont\u00e9s"
#   },
#   {
#     "id": "acons_d\u00e9mont\u00e9s_en_gabare~product_simplification",
#     "name": "acons d\u00e9mont\u00e9s en gabare"
#   },
#   {
#     "id": "acorus~product_simplification",
#     "name": "acorus"
#   },
#   {
#     "id": "acuirson~product_simplification",
#     "name": "acuirson"
#   },
#   {
#     "id": "acume_de_cuivre~product_simplification",
#     "name": "acume de cuivre"
#   },
#   {
#     "id": "ac\u00e9tates_d'\u00e9tain~product_simplification",
#     "name": "ac\u00e9tates d'\u00e9tain"
#   },
#   {
#     "id": "ac\u00e9tates_de_fer~product_simplification",
#     "name": "ac\u00e9tates de fer"
#   },
#   {
#     "id": "ac\u00e9tates_de_plomb~product_simplification",
#     "name": "ac\u00e9tates de plomb"
#   },
#   {
#     "id": "ac\u00e9tates_de_plomb_sel_de_Saturne~product_simplification",
#     "name": "ac\u00e9tates de plomb sel de Saturne"
#   },
#   {
#     "id": "ac\u00e9tates_de_potasse_et_de_soudes~product_simplification",
#     "name": "ac\u00e9tates de potasse et de soudes"
#   },
#   {
#     "id": "ac\u00e9tates_de_sel_d'\u00e9tain~product_simplification",
#     "name": "ac\u00e9tates de sel d'\u00e9tain"
#   },
#   {
#     "id": "adatais~product_simplification",
#     "name": "adatais"
#   },
#   {
#     "id": "aff\u00fbts~product_simplification",
#     "name": "aff\u00fbts"
#   },
#   {
#     "id": "aff\u00fbts_de_bois~product_simplification",
#     "name": "aff\u00fbts de bois"
#   },
#   {
#     "id": "aff\u00fbts_de_canons~product_simplification",
#     "name": "aff\u00fbts de canons"
#   },
#   {
#     "id": "aff\u00fbts_de_fer~product_simplification",
#     "name": "aff\u00fbts de fer"
#   },
#   {
#     "id": "aff\u00fbts_de_fusils~product_simplification",
#     "name": "aff\u00fbts de fusils"
#   },
#   {
#     "id": "aff\u00fbts_de_f\u00fbts_\u00e0_canons~product_simplification",
#     "name": "aff\u00fbts de f\u00fbts \u00e0 canons"
#   },
#   {
#     "id": "aff\u00fbts_et_canons~product_simplification",
#     "name": "aff\u00fbts et canons"
#   },
#   {
#     "id": "agaric~product_simplification",
#     "name": "agaric"
#   },
#   {
#     "id": "agaric_amadouvier~product_simplification",
#     "name": "agaric amadouvier"
#   },
#   {
#     "id": "agaric_amadouvier_brut~product_simplification",
#     "name": "agaric amadouvier brut"
#   },
#   {
#     "id": "agaric_amadouvier_brut_et_pr\u00e9par\u00e9~product_simplification",
#     "name": "agaric amadouvier brut et pr\u00e9par\u00e9"
#   },
#   {
#     "id": "agaric_amadouvier_pr\u00e9par\u00e9~product_simplification",
#     "name": "agaric amadouvier pr\u00e9par\u00e9"
#   },
#   {
#     "id": "agaric_brut_et_pr\u00e9par\u00e9~product_simplification",
#     "name": "agaric brut et pr\u00e9par\u00e9"
#   },
#   {
#     "id": "agaric_de_m\u00e9l\u00e8ze~product_simplification",
#     "name": "agaric de m\u00e9l\u00e8ze"
#   },
#   {
#     "id": "agaric_fin~product_simplification",
#     "name": "agaric fin"
#   },
#   {
#     "id": "agaric_gros~product_simplification",
#     "name": "agaric gros"
#   },
#   {
#     "id": "agate~product_simplification",
#     "name": "agate"
#   },
#   {
#     "id": "agate_autre_que_chique_et_ouvrages~product_simplification",
#     "name": "agate autre que chique et ouvrages"
#   },
#   {
#     "id": "agate_brute~product_simplification",
#     "name": "agate brute"
#   },
#   {
#     "id": "agate_en_pierres~product_simplification",
#     "name": "agate en pierres"
#   },
#   {
#     "id": "agate_fine~product_simplification",
#     "name": "agate fine"
#   },
#   {
#     "id": "agate_mont\u00e9e~product_simplification",
#     "name": "agate mont\u00e9e"
#   },
#   {
#     "id": "agneaux~product_simplification",
#     "name": "agneaux"
#   },
#   {
#     "id": "agneaux_communs~product_simplification",
#     "name": "agneaux communs"
#   },
#   {
#     "id": "agneaux_en_vie~product_simplification",
#     "name": "agneaux en vie"
#   },
#   {
#     "id": "agneaux_et_cabris~product_simplification",
#     "name": "agneaux et cabris"
#   },
#   {
#     "id": "agneaux_m\u00e9rinos_et_m\u00e9tis~product_simplification",
#     "name": "agneaux m\u00e9rinos et m\u00e9tis"
#   },
#   {
#     "id": "agnelines_et_crottelins~product_simplification",
#     "name": "agnelines et crottelins"
#   },
#   {
#     "id": "agobille~product_simplification",
#     "name": "agobille"
#   },
#   {
#     "id": "agoutals~product_simplification",
#     "name": "agoutals"
#   },
#   {
#     "id": "agoutals_de_bois~product_simplification",
#     "name": "agoutals de bois"
#   },
#   {
#     "id": "agr\u00e8s~product_simplification",
#     "name": "agr\u00e8s"
#   },
#   {
#     "id": "agr\u00e8s_apparaux_de_navire_et_embarcations~product_simplification",
#     "name": "agr\u00e8s apparaux de navire et embarcations"
#   },
#   {
#     "id": "agr\u00e8s_apparaux_et_embarcations~product_simplification",
#     "name": "agr\u00e8s apparaux et embarcations"
#   },
#   {
#     "id": "agr\u00e8s_de_navire_et_jeux_de_voile~product_simplification",
#     "name": "agr\u00e8s de navire et jeux de voile"
#   },
#   {
#     "id": "agr\u00e8s_et_apparaux~product_simplification",
#     "name": "agr\u00e8s et apparaux"
#   },
#   {
#     "id": "agr\u00e8s_et_apparaux_d'or_navire~product_simplification",
#     "name": "agr\u00e8s et apparaux d'or navire"
#   },
#   {
#     "id": "agr\u00e8s_et_b\u00e2timents_de_mer~product_simplification",
#     "name": "agr\u00e8s et b\u00e2timents de mer"
#   },
#   {
#     "id": "agr\u00e8s_et_embarcations~product_simplification",
#     "name": "agr\u00e8s et embarcations"
#   },
#   {
#     "id": "agr\u00e8s_et_voile_de_navire~product_simplification",
#     "name": "agr\u00e8s et voile de navire"
#   },
#   {
#     "id": "agr\u00e9ment~product_simplification",
#     "name": "agr\u00e9ment"
#   },
#   {
#     "id": "agr\u00e9ment_au_quart~product_simplification",
#     "name": "agr\u00e9ment au quart"
#   },
#   {
#     "id": "agr\u00e9ment_d'argent~product_simplification",
#     "name": "agr\u00e9ment d'argent"
#   },
#   {
#     "id": "agr\u00e9ment_d'or~product_simplification",
#     "name": "agr\u00e9ment d'or"
#   },
#   {
#     "id": "agr\u00e9ment_d'or_et_d'argent~product_simplification",
#     "name": "agr\u00e9ment d'or et d'argent"
#   },
#   {
#     "id": "agr\u00e9ment_de_fil~product_simplification",
#     "name": "agr\u00e9ment de fil"
#   },
#   {
#     "id": "agr\u00e9ment_de_fil_et_de_soie~product_simplification",
#     "name": "agr\u00e9ment de fil et de soie"
#   },
#   {
#     "id": "agr\u00e9ment_de_fleur~product_simplification",
#     "name": "agr\u00e9ment de fleur"
#   },
#   {
#     "id": "agr\u00e9ment_de_soie~product_simplification",
#     "name": "agr\u00e9ment de soie"
#   },
#   {
#     "id": "agr\u00e9ment_de_soie_et_d'argent~product_simplification",
#     "name": "agr\u00e9ment de soie et d'argent"
#   },
#   {
#     "id": "agr\u00e9ment_de_soie_or_et_argent_faux~product_simplification",
#     "name": "agr\u00e9ment de soie or et argent faux"
#   },
#   {
#     "id": "agr\u00e9ments_de_soie_et_milleret~product_simplification",
#     "name": "agr\u00e9ments de soie et milleret"
#   },
#   {
#     "id": "agr\u00e9ments_et_milleret~product_simplification",
#     "name": "agr\u00e9ments et milleret"
#   },
#   {
#     "id": "aigles~product_simplification",
#     "name": "aigles"
#   },
#   {
#     "id": "aigre_de_cidre~product_simplification",
#     "name": "aigre de cidre"
#   },
#   {
#     "id": "aigre_de_c\u00e8dre~product_simplification",
#     "name": "aigre de c\u00e8dre"
#   },
#   {
#     "id": "aigre_de_vitriol~product_simplification",
#     "name": "aigre de vitriol"
#   },
#   {
#     "id": "aigrettes~product_simplification",
#     "name": "aigrettes"
#   },
#   {
#     "id": "aigrettes_de_fil_d'or_et_d'argent~product_simplification",
#     "name": "aigrettes de fil d'or et d'argent"
#   },
#   {
#     "id": "aigrettes_de_soie~product_simplification",
#     "name": "aigrettes de soie"
#   },
#   {
#     "id": "aigrettes_de_soie_et_argent~product_simplification",
#     "name": "aigrettes de soie et argent"
#   },
#   {
#     "id": "aigrettes_et_bavolets~product_simplification",
#     "name": "aigrettes et bavolets"
#   },
#   {
#     "id": "aiguilles~product_simplification",
#     "name": "aiguilles"
#   },
#   {
#     "id": "aiguilles_d'emballage~product_simplification",
#     "name": "aiguilles d'emballage"
#   },
#   {
#     "id": "aiguilles_de_mercerie_fine~product_simplification",
#     "name": "aiguilles de mercerie fine"
#   },
#   {
#     "id": "aiguilles_epars_de_sapin~product_simplification",
#     "name": "aiguilles epars de sapin"
#   },
#   {
#     "id": "aiguilles_et_mercerie_fine~product_simplification",
#     "name": "aiguilles et mercerie fine"
#   },
#   {
#     "id": "aiguilles_et_\u00e9pingles~product_simplification",
#     "name": "aiguilles et \u00e9pingles"
#   },
#   {
#     "id": "aiguilles_et_\u00e9pingles_de_mercerie_fine~product_simplification",
#     "name": "aiguilles et \u00e9pingles de mercerie fine"
#   },
#   {
#     "id": "aiguilles_grosses~product_simplification",
#     "name": "aiguilles grosses"
#   },
#   {
#     "id": "aiguilles_pour_voile~product_simplification",
#     "name": "aiguilles pour voile"
#   },
#   {
#     "id": "aiguilles_\u00e0_bo\u00eetes~product_simplification",
#     "name": "aiguilles \u00e0 bo\u00eetes"
#   },
#   {
#     "id": "aiguilles_\u00e0_coudre~product_simplification",
#     "name": "aiguilles \u00e0 coudre"
#   },
#   {
#     "id": "aiguilles_\u00e0_coudre_voiles~product_simplification",
#     "name": "aiguilles \u00e0 coudre voiles"
#   },
#   {
#     "id": "aiguilles_\u00e0_ralingue~product_simplification",
#     "name": "aiguilles \u00e0 ralingue"
#   },
#   {
#     "id": "aiguilles_\u00e0_tabac~product_simplification",
#     "name": "aiguilles \u00e0 tabac"
#   },
#   {
#     "id": "aiguilles_\u00e0_toile~product_simplification",
#     "name": "aiguilles \u00e0 toile"
#   },
#   {
#     "id": "aiguillettes~product_simplification",
#     "name": "aiguillettes"
#   },
#   {
#     "id": "aigui\u00e8res_d'\u00e9tain~product_simplification",
#     "name": "aigui\u00e8res d'\u00e9tain"
#   },
#   {
#     "id": "ail~product_simplification",
#     "name": "ail"
#   },
#   {
#     "id": "ailes~product_simplification",
#     "name": "ailes"
#   },
#   {
#     "id": "ailes_de_fl\u00e9aux~product_simplification",
#     "name": "ailes de fl\u00e9aux"
#   },
#   {
#     "id": "ailes_de_moulins~product_simplification",
#     "name": "ailes de moulins"
#   },
#   {
#     "id": "ailor~product_simplification",
#     "name": "ailor"
#   },
#   {
#     "id": "ails~product_simplification",
#     "name": "ails"
#   },
#   {
#     "id": "ails_blancs_\u00e0_casser~product_simplification",
#     "name": "ails blancs \u00e0 casser"
#   },
#   {
#     "id": "ails_\u00e0_fauches~product_simplification",
#     "name": "ails \u00e0 fauches"
#   },
#   {
#     "id": "aimant~product_simplification",
#     "name": "aimant"
#   },
#   {
#     "id": "ains_et_lignes_\u00e0_p\u00eacher~product_simplification",
#     "name": "ains et lignes \u00e0 p\u00eacher"
#   },
#   {
#     "id": "ains_\u00e0_p\u00eacher~product_simplification",
#     "name": "ains \u00e0 p\u00eacher"
#   },
#   {
#     "id": "airain~product_simplification",
#     "name": "airain"
#   },
#   {
#     "id": "airain_non_ouvr\u00e9~product_simplification",
#     "name": "airain non ouvr\u00e9"
#   },
#   {
#     "id": "ajamis~product_simplification",
#     "name": "ajamis"
#   },
#   {
#     "id": "ajustements~product_simplification",
#     "name": "ajustements"
#   },
#   {
#     "id": "ajustements_de_femme~product_simplification",
#     "name": "ajustements de femme"
#   },
#   {
#     "id": "ajustements_de_soie~product_simplification",
#     "name": "ajustements de soie"
#   },
#   {
#     "id": "alambics~product_simplification",
#     "name": "alambics"
#   },
#   {
#     "id": "alambics_d'\u00e9tain~product_simplification",
#     "name": "alambics d'\u00e9tain"
#   },
#   {
#     "id": "alambics_de_cuivre~product_simplification",
#     "name": "alambics de cuivre"
#   },
#   {
#     "id": "alambics_de_terre~product_simplification",
#     "name": "alambics de terre"
#   },
#   {
#     "id": "alana~product_simplification",
#     "name": "alana"
#   },
#   {
#     "id": "alazar~product_simplification",
#     "name": "alazar"
#   },
#   {
#     "id": "alb\u00e2tre~product_simplification",
#     "name": "alb\u00e2tre"
#   },
#   {
#     "id": "alb\u00e2tre_brut~product_simplification",
#     "name": "alb\u00e2tre brut"
#   },
#   {
#     "id": "alb\u00e2tre_et_marbre_brut_et_poli~product_simplification",
#     "name": "alb\u00e2tre et marbre brut et poli"
#   },
#   {
#     "id": "alb\u00e2tre_moul\u00e9_poli_ou_sculpt\u00e9~product_simplification",
#     "name": "alb\u00e2tre moul\u00e9 poli ou sculpt\u00e9"
#   },
#   {
#     "id": "alcalis_autre_que_natron_et_soudes~product_simplification",
#     "name": "alcalis autre que natron et soudes"
#   },
#   {
#     "id": "alcalis_salin~product_simplification",
#     "name": "alcalis salin"
#   },
#   {
#     "id": "alibanies~product_simplification",
#     "name": "alibanies"
#   },
#   {
#     "id": "alicot~product_simplification",
#     "name": "alicot"
#   },
#   {
#     "id": "alizari~product_simplification",
#     "name": "alizari"
#   },
#   {
#     "id": "alizari_et_garance~product_simplification",
#     "name": "alizari et garance"
#   },
#   {
#     "id": "alizari_s\u00e8che~product_simplification",
#     "name": "alizari s\u00e8che"
#   },
#   {
#     "id": "alkerm\u00e8s_en_grains~product_simplification",
#     "name": "alkerm\u00e8s en grains"
#   },
#   {
#     "id": "alkerm\u00e9s~product_simplification",
#     "name": "alkerm\u00e9s"
#   },
#   {
#     "id": "allaya~product_simplification",
#     "name": "allaya"
#   },
#   {
#     "id": "alleaux~product_simplification",
#     "name": "alleaux"
#   },
#   {
#     "id": "allumettes~product_simplification",
#     "name": "allumettes"
#   },
#   {
#     "id": "allumettes_de_coton~product_simplification",
#     "name": "allumettes de coton"
#   },
#   {
#     "id": "allumettes_de_m\u00eache_soufr\u00e9e~product_simplification",
#     "name": "allumettes de m\u00eache soufr\u00e9e"
#   },
#   {
#     "id": "allumettes_drogu\u00e9es~product_simplification",
#     "name": "allumettes drogu\u00e9es"
#   },
#   {
#     "id": "allumettes_op\u00e9r\u00e9es_et_soufr\u00e9es~product_simplification",
#     "name": "allumettes op\u00e9r\u00e9es et soufr\u00e9es"
#   },
#   {
#     "id": "allumettes_soufr\u00e9es~product_simplification",
#     "name": "allumettes soufr\u00e9es"
#   },
#   {
#     "id": "allumettes_\u00e0_vin~product_simplification",
#     "name": "allumettes \u00e0 vin"
#   },
#   {
#     "id": "allumettes_\u00e9pic\u00e9e~product_simplification",
#     "name": "allumettes \u00e9pic\u00e9e"
#   },
#   {
#     "id": "almagro_ou_crayon_rouge~product_simplification",
#     "name": "almagro ou crayon rouge"
#   },
#   {
#     "id": "almanachs~product_simplification",
#     "name": "almanachs"
#   },
#   {
#     "id": "almanachs_broch\u00e9s~product_simplification",
#     "name": "almanachs broch\u00e9s"
#   },
#   {
#     "id": "almanachs_en_blancs~product_simplification",
#     "name": "almanachs en blancs"
#   },
#   {
#     "id": "almanachs_enjoliv\u00e9s~product_simplification",
#     "name": "almanachs enjoliv\u00e9s"
#   },
#   {
#     "id": "almanachs_reli\u00e9s~product_simplification",
#     "name": "almanachs reli\u00e9s"
#   },
#   {
#     "id": "aloiset~product_simplification",
#     "name": "aloiset"
#   },
#   {
#     "id": "alose~product_simplification",
#     "name": "alose"
#   },
#   {
#     "id": "alose_fum\u00e9e~product_simplification",
#     "name": "alose fum\u00e9e"
#   },
#   {
#     "id": "alose_sal\u00e9e~product_simplification",
#     "name": "alose sal\u00e9e"
#   },
#   {
#     "id": "aloues~product_simplification",
#     "name": "aloues"
#   },
#   {
#     "id": "alouettes~product_simplification",
#     "name": "alouettes"
#   },
#   {
#     "id": "alo\u00e8s~product_simplification",
#     "name": "alo\u00e8s"
#   },
#   {
#     "id": "alo\u00e8s_cabalin~product_simplification",
#     "name": "alo\u00e8s cabalin"
#   },
#   {
#     "id": "alo\u00e8s_commun~product_simplification",
#     "name": "alo\u00e8s commun"
#   },
#   {
#     "id": "alo\u00e8s_et_opium~product_simplification",
#     "name": "alo\u00e8s et opium"
#   },
#   {
#     "id": "alo\u00e8s_h\u00e9patique~product_simplification",
#     "name": "alo\u00e8s h\u00e9patique"
#   },
#   {
#     "id": "alo\u00e8s_moyen~product_simplification",
#     "name": "alo\u00e8s moyen"
#   },
#   {
#     "id": "alpargate~product_simplification",
#     "name": "alpargate"
#   },
#   {
#     "id": "alphabets~product_simplification",
#     "name": "alphabets"
#   },
#   {
#     "id": "alpiste~product_simplification",
#     "name": "alpiste"
#   },
#   {
#     "id": "alpiste_et_millet~product_simplification",
#     "name": "alpiste et millet"
#   },
#   {
#     "id": "alquifoux~product_simplification",
#     "name": "alquifoux"
#   },
#   {
#     "id": "alquifoux_en_gal\u00e8ne~product_simplification",
#     "name": "alquifoux en gal\u00e8ne"
#   },
#   {
#     "id": "alquifoux_et_mine_de_plomb~product_simplification",
#     "name": "alquifoux et mine de plomb"
#   },
#   {
#     "id": "alquifoux_mine_de_plomb_ou_graphite~product_simplification",
#     "name": "alquifoux mine de plomb ou graphite"
#   },
#   {
#     "id": "alquifoux_ou_mine_de_plomb~product_simplification",
#     "name": "alquifoux ou mine de plomb"
#   },
#   {
#     "id": "alquifoux_sable_plombif\u00e8re~product_simplification",
#     "name": "alquifoux sable plombif\u00e8re"
#   },
#   {
#     "id": "alquitra~product_simplification",
#     "name": "alquitra"
#   },
#   {
#     "id": "alto_basses_chapeaux_chinois_clarinettes_cors_cymbales_fifres_et_flageolets_fl\u00fbtes_guitare_haut-bois_serinettes_serpent_tambours_trompettes_et_violons_basses~product_simplification",
#     "name": "alto basses chapeaux chinois clarinettes cors cymbales fifres et flageolets fl\u00fbtes guitare haut-bois serinettes serpent tambours trompettes et violons basses"
#   },
#   {
#     "id": "alto_basses_contrebasses_guitare_lyres_violes_violons~product_simplification",
#     "name": "alto basses contrebasses guitare lyres violes violons"
#   },
#   {
#     "id": "alto_bassons_guitare_violons~product_simplification",
#     "name": "alto bassons guitare violons"
#   },
#   {
#     "id": "alun~product_simplification",
#     "name": "alun"
#   },
#   {
#     "id": "alun_autre_que_br\u00fbl\u00e9_ou_calcin\u00e9~product_simplification",
#     "name": "alun autre que br\u00fbl\u00e9 ou calcin\u00e9"
#   },
#   {
#     "id": "alun_bon~product_simplification",
#     "name": "alun bon"
#   },
#   {
#     "id": "alun_br\u00fbl\u00e9~product_simplification",
#     "name": "alun br\u00fbl\u00e9"
#   },
#   {
#     "id": "alun_commun~product_simplification",
#     "name": "alun commun"
#   },
#   {
#     "id": "alun_de_glace~product_simplification",
#     "name": "alun de glace"
#   },
#   {
#     "id": "alun_de_roche~product_simplification",
#     "name": "alun de roche"
#   },
#   {
#     "id": "alun_de_Rome~product_simplification",
#     "name": "alun de Rome"
#   },
#   {
#     "id": "alun_de_Rome_fin_ros\u00e9~product_simplification",
#     "name": "alun de Rome fin ros\u00e9"
#   },
#   {
#     "id": "alun_de_Rouen~product_simplification",
#     "name": "alun de Rouen"
#   },
#   {
#     "id": "alun_de_Surde~product_simplification",
#     "name": "alun de Surde"
#   },
#   {
#     "id": "alun_du_Levant~product_simplification",
#     "name": "alun du Levant"
#   },
#   {
#     "id": "alun_en_dracy~product_simplification",
#     "name": "alun en dracy"
#   },
#   {
#     "id": "alun_en_rame~product_simplification",
#     "name": "alun en rame"
#   },
#   {
#     "id": "alun_g\u00e2t\u00e9~product_simplification",
#     "name": "alun g\u00e2t\u00e9"
#   },
#   {
#     "id": "alun_ordinaire~product_simplification",
#     "name": "alun ordinaire"
#   },
#   {
#     "id": "alun_\u00e0_cordonnier~product_simplification",
#     "name": "alun \u00e0 cordonnier"
#   },
#   {
#     "id": "alv\u00e9s~product_simplification",
#     "name": "alv\u00e9s"
#   },
#   {
#     "id": "al\u00e8nes~product_simplification",
#     "name": "al\u00e8nes"
#   },
#   {
#     "id": "amadou~product_simplification",
#     "name": "amadou"
#   },
#   {
#     "id": "amadou_et_agaric_amadouvier~product_simplification",
#     "name": "amadou et agaric amadouvier"
#   },
#   {
#     "id": "amandes~product_simplification",
#     "name": "amandes"
#   },
#   {
#     "id": "amandes_am\u00e8res~product_simplification",
#     "name": "amandes am\u00e8res"
#   },
#   {
#     "id": "amandes_arachis_noisettes_noix_noyaux~product_simplification",
#     "name": "amandes arachis noisettes noix noyaux"
#   },
#   {
#     "id": "amandes_cass\u00e9e~product_simplification",
#     "name": "amandes cass\u00e9e"
#   },
#   {
#     "id": "amandes_cass\u00e9es~product_simplification",
#     "name": "amandes cass\u00e9es"
#   },
#   {
#     "id": "amandes_cass\u00e9es_ou_en_coque~product_simplification",
#     "name": "amandes cass\u00e9es ou en coque"
#   },
#   {
#     "id": "amandes_courtes~product_simplification",
#     "name": "amandes courtes"
#   },
#   {
#     "id": "amandes_douces~product_simplification",
#     "name": "amandes douces"
#   },
#   {
#     "id": "amandes_en_coque~product_simplification",
#     "name": "amandes en coque"
#   },
#   {
#     "id": "amandes_et_figue_et_raisin~product_simplification",
#     "name": "amandes et figue et raisin"
#   },
#   {
#     "id": "amandes_et_pelures_et_prunes_et_raisin~product_simplification",
#     "name": "amandes et pelures et prunes et raisin"
#   },
#   {
#     "id": "amandes_et_pruneaux~product_simplification",
#     "name": "amandes et pruneaux"
#   },
#   {
#     "id": "amandes_et_raisin_sec~product_simplification",
#     "name": "amandes et raisin sec"
#   },
#   {
#     "id": "amandes_et_raisin_sec_et_savon~product_simplification",
#     "name": "amandes et raisin sec et savon"
#   },
#   {
#     "id": "amandes_et_savon~product_simplification",
#     "name": "amandes et savon"
#   },
#   {
#     "id": "amandes_et_sucre~product_simplification",
#     "name": "amandes et sucre"
#   },
#   {
#     "id": "amandes_et_verdet~product_simplification",
#     "name": "amandes et verdet"
#   },
#   {
#     "id": "amandes_fra\u00eeches~product_simplification",
#     "name": "amandes fra\u00eeches"
#   },
#   {
#     "id": "amandes_longues~product_simplification",
#     "name": "amandes longues"
#   },
#   {
#     "id": "amandes_mond\u00e9es~product_simplification",
#     "name": "amandes mond\u00e9es"
#   },
#   {
#     "id": "amandes_s\u00e8ches~product_simplification",
#     "name": "amandes s\u00e8ches"
#   },
#   {
#     "id": "amandes_s\u00e8ches_et_figue_s\u00e8che_et_???~product_simplification",
#     "name": "amandes s\u00e8ches et figue s\u00e8che et ???"
#   },
#   {
#     "id": "amandes_s\u00e8ches_et_figue_s\u00e8che_et_raisin_sec~product_simplification",
#     "name": "amandes s\u00e8ches et figue s\u00e8che et raisin sec"
#   },
#   {
#     "id": "amandes_\u00e0_la_praline~product_simplification",
#     "name": "amandes \u00e0 la praline"
#   },
#   {
#     "id": "amarinage~product_simplification",
#     "name": "amarinage"
#   },
#   {
#     "id": "amarine~product_simplification",
#     "name": "amarine"
#   },
#   {
#     "id": "ambrain_\u00e0_grande_barrique~product_simplification",
#     "name": "ambrain \u00e0 grande barrique"
#   },
#   {
#     "id": "ambre~product_simplification",
#     "name": "ambre"
#   },
#   {
#     "id": "ambre_blanc~product_simplification",
#     "name": "ambre blanc"
#   },
#   {
#     "id": "ambre_brut~product_simplification",
#     "name": "ambre brut"
#   },
#   {
#     "id": "ambre_carab\u00e9~product_simplification",
#     "name": "ambre carab\u00e9"
#   },
#   {
#     "id": "ambre_carab\u00e9_jaune~product_simplification",
#     "name": "ambre carab\u00e9 jaune"
#   },
#   {
#     "id": "ambre_en_grains~product_simplification",
#     "name": "ambre en grains"
#   },
#   {
#     "id": "ambre_et_corail~product_simplification",
#     "name": "ambre et corail"
#   },
#   {
#     "id": "ambre_gris~product_simplification",
#     "name": "ambre gris"
#   },
#   {
#     "id": "ambre_jaune~product_simplification",
#     "name": "ambre jaune"
#   },
#   {
#     "id": "ambre_moulu~product_simplification",
#     "name": "ambre moulu"
#   },
#   {
#     "id": "amer~product_simplification",
#     "name": "amer"
#   },
#   {
#     "id": "amer_de_laine~product_simplification",
#     "name": "amer de laine"
#   },
#   {
#     "id": "amertis~product_simplification",
#     "name": "amertis"
#   },
#   {
#     "id": "ameublement~product_simplification",
#     "name": "ameublement"
#   },
#   {
#     "id": "ameublement_de_chitte~product_simplification",
#     "name": "ameublement de chitte"
#   },
#   {
#     "id": "ami_de_toil\u00e9~product_simplification",
#     "name": "ami de toil\u00e9"
#   },
#   {
#     "id": "amidon~product_simplification",
#     "name": "amidon"
#   },
#   {
#     "id": "amidon_alun~product_simplification",
#     "name": "amidon alun"
#   },
#   {
#     "id": "amidon_en_grains~product_simplification",
#     "name": "amidon en grains"
#   },
#   {
#     "id": "amidon_en_poudre~product_simplification",
#     "name": "amidon en poudre"
#   },
#   {
#     "id": "amidon_et_poudre_\u00e0_poudrer~product_simplification",
#     "name": "amidon et poudre \u00e0 poudrer"
#   },
#   {
#     "id": "ammoniac~product_simplification",
#     "name": "ammoniac"
#   },
#   {
#     "id": "ammoniac_et_sel~product_simplification",
#     "name": "ammoniac et sel"
#   },
#   {
#     "id": "ammonium~product_simplification",
#     "name": "ammonium"
#   },
#   {
#     "id": "amomum~product_simplification",
#     "name": "amomum"
#   },
#   {
#     "id": "amomum_et_f\u00e8ves_de_tonka_et_noix_de_ravensara~product_simplification",
#     "name": "amomum et f\u00e8ves de tonka et noix de ravensara"
#   },
#   {
#     "id": "amomum_verum~product_simplification",
#     "name": "amomum verum"
#   },
#   {
#     "id": "amurca~product_simplification",
#     "name": "amurca"
#   },
#   {
#     "id": "anabasse~product_simplification",
#     "name": "anabasse"
#   },
#   {
#     "id": "anabasse_bajutapau~product_simplification",
#     "name": "anabasse bajutapau"
#   },
#   {
#     "id": "anabasse_corat_nicaneas_platille~product_simplification",
#     "name": "anabasse corat nicaneas platille"
#   },
#   {
#     "id": "anacardes~product_simplification",
#     "name": "anacardes"
#   },
#   {
#     "id": "anacoste~product_simplification",
#     "name": "anacoste"
#   },
#   {
#     "id": "ananas~product_simplification",
#     "name": "ananas"
#   },
#   {
#     "id": "ananas_confit~product_simplification",
#     "name": "ananas confit"
#   },
#   {
#     "id": "ananas_et_pommes_de_grenade~product_simplification",
#     "name": "ananas et pommes de grenade"
#   },
#   {
#     "id": "ananas_plant\u00e9~product_simplification",
#     "name": "ananas plant\u00e9"
#   },
#   {
#     "id": "anatomie~product_simplification",
#     "name": "anatomie"
#   },
#   {
#     "id": "anatose~product_simplification",
#     "name": "anatose"
#   },
#   {
#     "id": "anches_de_tonneaux~product_simplification",
#     "name": "anches de tonneaux"
#   },
#   {
#     "id": "anchois~product_simplification",
#     "name": "anchois"
#   },
#   {
#     "id": "anchois_c\u00e2pres_et_olives~product_simplification",
#     "name": "anchois c\u00e2pres et olives"
#   },
#   {
#     "id": "anchois_c\u00e2pres_etc.~product_simplification",
#     "name": "anchois c\u00e2pres etc."
#   },
#   {
#     "id": "anchois_c\u00e2pres_olives~product_simplification",
#     "name": "anchois c\u00e2pres olives"
#   },
#   {
#     "id": "anchois_et_boutargue~product_simplification",
#     "name": "anchois et boutargue"
#   },
#   {
#     "id": "anchois_et_c\u00e2pres~product_simplification",
#     "name": "anchois et c\u00e2pres"
#   },
#   {
#     "id": "anchois_et_sardes~product_simplification",
#     "name": "anchois et sardes"
#   },
#   {
#     "id": "anchois_et_sardines~product_simplification",
#     "name": "anchois et sardines"
#   },
#   {
#     "id": "anchois_marin\u00e9~product_simplification",
#     "name": "anchois marin\u00e9"
#   },
#   {
#     "id": "anchois_marin\u00e9_et_sal\u00e9~product_simplification",
#     "name": "anchois marin\u00e9 et sal\u00e9"
#   },
#   {
#     "id": "anchois_sal\u00e9_et_marin\u00e9~product_simplification",
#     "name": "anchois sal\u00e9 et marin\u00e9"
#   },
#   {
#     "id": "anchois_sal\u00e9s~product_simplification",
#     "name": "anchois sal\u00e9s"
#   },
#   {
#     "id": "anchois_sal\u00e9s_et_marin\u00e9s~product_simplification",
#     "name": "anchois sal\u00e9s et marin\u00e9s"
#   },
#   {
#     "id": "ancres~product_simplification",
#     "name": "ancres"
#   },
#   {
#     "id": "ancres_de_chaudon~product_simplification",
#     "name": "ancres de chaudon"
#   },
#   {
#     "id": "ancres_de_fer~product_simplification",
#     "name": "ancres de fer"
#   },
#   {
#     "id": "ancres_de_fer_au-dessus_de_250_kilogrammes~product_simplification",
#     "name": "ancres de fer au-dessus de 250 kilogrammes"
#   },
#   {
#     "id": "ancres_de_fer_de_250_kilogrammes_et_au-dessous~product_simplification",
#     "name": "ancres de fer de 250 kilogrammes et au-dessous"
#   },
#   {
#     "id": "ancres_de_fer_et_embarcations~product_simplification",
#     "name": "ancres de fer et embarcations"
#   },
#   {
#     "id": "ancres_de_fer_\u00e0_chaudrons~product_simplification",
#     "name": "ancres de fer \u00e0 chaudrons"
#   },
#   {
#     "id": "ancres_et_embarcations~product_simplification",
#     "name": "ancres et embarcations"
#   },
#   {
#     "id": "ancres_et_grappins_de_fer~product_simplification",
#     "name": "ancres et grappins de fer"
#   },
#   {
#     "id": "ancres_gravel\u00e9es~product_simplification",
#     "name": "ancres gravel\u00e9es"
#   },
#   {
#     "id": "ancres_neuves~product_simplification",
#     "name": "ancres neuves"
#   },
#   {
#     "id": "ancres_vides~product_simplification",
#     "name": "ancres vides"
#   },
#   {
#     "id": "ancres_vieilles~product_simplification",
#     "name": "ancres vieilles"
#   },
#   {
#     "id": "ancres_vieilles_vides~product_simplification",
#     "name": "ancres vieilles vides"
#   },
#   {
#     "id": "andolium~product_simplification",
#     "name": "andolium"
#   },
#   {
#     "id": "andouilles~product_simplification",
#     "name": "andouilles"
#   },
#   {
#     "id": "andouillette~product_simplification",
#     "name": "andouillette"
#   },
#   {
#     "id": "anguilles~product_simplification",
#     "name": "anguilles"
#   },
#   {
#     "id": "anguilles_et_truites~product_simplification",
#     "name": "anguilles et truites"
#   },
#   {
#     "id": "anguilles_fra\u00eeches~product_simplification",
#     "name": "anguilles fra\u00eeches"
#   },
#   {
#     "id": "anguilles_marin\u00e9es~product_simplification",
#     "name": "anguilles marin\u00e9es"
#   },
#   {
#     "id": "anguilles_sal\u00e9es~product_simplification",
#     "name": "anguilles sal\u00e9es"
#   },
#   {
#     "id": "ang\u00e9lique~product_simplification",
#     "name": "ang\u00e9lique"
#   },
#   {
#     "id": "ang\u00e9lique_du_Roz\u00e8me~product_simplification",
#     "name": "ang\u00e9lique du Roz\u00e8me"
#   },
#   {
#     "id": "anille~product_simplification",
#     "name": "anille"
#   },
#   {
#     "id": "animaux~product_simplification",
#     "name": "animaux"
#   },
#   {
#     "id": "anis~product_simplification",
#     "name": "anis"
#   },
#   {
#     "id": "anis_et_rac_et_rhum_etc.~product_simplification",
#     "name": "anis et rac et rhum etc."
#   },
#   {
#     "id": "anis_et_sucre~product_simplification",
#     "name": "anis et sucre"
#   },
#   {
#     "id": "anis_vert~product_simplification",
#     "name": "anis vert"
#   },
#   {
#     "id": "anis_vert_\u00e0_distiller~product_simplification",
#     "name": "anis vert \u00e0 distiller"
#   },
#   {
#     "id": "anisette~product_simplification",
#     "name": "anisette"
#   },
#   {
#     "id": "anisette_au_fiasque~product_simplification",
#     "name": "anisette au fiasque"
#   },
#   {
#     "id": "anisette_de_Bordeaux~product_simplification",
#     "name": "anisette de Bordeaux"
#   },
#   {
#     "id": "anneau_de_cuivre~product_simplification",
#     "name": "anneau de cuivre"
#   },
#   {
#     "id": "anneau_de_fer~product_simplification",
#     "name": "anneau de fer"
#   },
#   {
#     "id": "anneaux_de_cuivre~product_simplification",
#     "name": "anneaux de cuivre"
#   },
#   {
#     "id": "anneaux_de_fer~product_simplification",
#     "name": "anneaux de fer"
#   },
#   {
#     "id": "anspects~product_simplification",
#     "name": "anspects"
#   },
#   {
#     "id": "anspects_de_3_\u00e0_4_pieds~product_simplification",
#     "name": "anspects de 3 \u00e0 4 pieds"
#   },
#   {
#     "id": "anspects_de_bois~product_simplification",
#     "name": "anspects de bois"
#   },
#   {
#     "id": "anspects_de_sapin~product_simplification",
#     "name": "anspects de sapin"
#   },
#   {
#     "id": "antale~product_simplification",
#     "name": "antale"
#   },
#   {
#     "id": "antale_et_cauris~product_simplification",
#     "name": "antale et cauris"
#   },
#   {
#     "id": "antenelle~product_simplification",
#     "name": "antenelle"
#   },
#   {
#     "id": "antennes~product_simplification",
#     "name": "antennes"
#   },
#   {
#     "id": "antennes_et_m\u00e2ts_de_bateaux~product_simplification",
#     "name": "antennes et m\u00e2ts de bateaux"
#   },
#   {
#     "id": "antimoine~product_simplification",
#     "name": "antimoine"
#   },
#   {
#     "id": "antimoine_cru~product_simplification",
#     "name": "antimoine cru"
#   },
#   {
#     "id": "antimoine_m\u00e9tallique_et_sulfur\u00e9~product_simplification",
#     "name": "antimoine m\u00e9tallique et sulfur\u00e9"
#   },
#   {
#     "id": "antimoine_pr\u00e9par\u00e9~product_simplification",
#     "name": "antimoine pr\u00e9par\u00e9"
#   },
#   {
#     "id": "antimoine_vert~product_simplification",
#     "name": "antimoine vert"
#   },
#   {
#     "id": "antofle~product_simplification",
#     "name": "antofle"
#   },
#   {
#     "id": "antofle_de_girofle~product_simplification",
#     "name": "antofle de girofle"
#   },
#   {
#     "id": "apasier~product_simplification",
#     "name": "apasier"
#   },
#   {
#     "id": "apier~product_simplification",
#     "name": "apier"
#   },
#   {
#     "id": "apios~product_simplification",
#     "name": "apios"
#   },
#   {
#     "id": "apparaux~product_simplification",
#     "name": "apparaux"
#   },
#   {
#     "id": "apparaux_et_b\u00e2timents_de_mer~product_simplification",
#     "name": "apparaux et b\u00e2timents de mer"
#   },
#   {
#     "id": "appr\u00eats~product_simplification",
#     "name": "appr\u00eats"
#   },
#   {
#     "id": "appr\u00eat\u00e9e_pour_parchemins~product_simplification",
#     "name": "appr\u00eat\u00e9e pour parchemins"
#   },
#   {
#     "id": "appr\u00eat\u00e9e_\u00e0_toiler_les_livres~product_simplification",
#     "name": "appr\u00eat\u00e9e \u00e0 toiler les livres"
#   },
#   {
#     "id": "arachis_olives_fra\u00eeches~product_simplification",
#     "name": "arachis olives fra\u00eeches"
#   },
#   {
#     "id": "arains~product_simplification",
#     "name": "arains"
#   },
#   {
#     "id": "arak~product_simplification",
#     "name": "arak"
#   },
#   {
#     "id": "arbal\u00e8tes~product_simplification",
#     "name": "arbal\u00e8tes"
#   },
#   {
#     "id": "arbal\u00e8trie_et_cartes_marines~product_simplification",
#     "name": "arbal\u00e8trie et cartes marines"
#   },
#   {
#     "id": "arbres~product_simplification",
#     "name": "arbres"
#   },
#   {
#     "id": "arbres_ch\u00e2taignier~product_simplification",
#     "name": "arbres ch\u00e2taignier"
#   },
#   {
#     "id": "arbres_d'_???~product_simplification",
#     "name": "arbres d' ???"
#   },
#   {
#     "id": "arbres_d'auban~product_simplification",
#     "name": "arbres d'auban"
#   },
#   {
#     "id": "arbres_de_sapin~product_simplification",
#     "name": "arbres de sapin"
#   },
#   {
#     "id": "arbres_et_arbrisseaux~product_simplification",
#     "name": "arbres et arbrisseaux"
#   },
#   {
#     "id": "arbres_et_arbrisseaux_sauvages~product_simplification",
#     "name": "arbres et arbrisseaux sauvages"
#   },
#   {
#     "id": "arbres_et_arbrisseaux_\u00e0_fruits~product_simplification",
#     "name": "arbres et arbrisseaux \u00e0 fruits"
#   },
#   {
#     "id": "arbres_et_arbustes~product_simplification",
#     "name": "arbres et arbustes"
#   },
#   {
#     "id": "arbres_et_plants~product_simplification",
#     "name": "arbres et plants"
#   },
#   {
#     "id": "arbres_fruitiers~product_simplification",
#     "name": "arbres fruitiers"
#   },
#   {
#     "id": "arbres_marronniers_\u00e0_planter~product_simplification",
#     "name": "arbres marronniers \u00e0 planter"
#   },
#   {
#     "id": "arbres_nains~product_simplification",
#     "name": "arbres nains"
#   },
#   {
#     "id": "arbres_tilleul~product_simplification",
#     "name": "arbres tilleul"
#   },
#   {
#     "id": "arbres_\u00e0_fruits~product_simplification",
#     "name": "arbres \u00e0 fruits"
#   },
#   {
#     "id": "arbres_\u00e0_planter~product_simplification",
#     "name": "arbres \u00e0 planter"
#   },
#   {
#     "id": "arbrisseaux~product_simplification",
#     "name": "arbrisseaux"
#   },
#   {
#     "id": "arbustes~product_simplification",
#     "name": "arbustes"
#   },
#   {
#     "id": "arcanette~product_simplification",
#     "name": "arcanette"
#   },
#   {
#     "id": "arcanie~product_simplification",
#     "name": "arcanie"
#   },
#   {
#     "id": "arcanson~product_simplification",
#     "name": "arcanson"
#   },
#   {
#     "id": "arcanum_duplicatum~product_simplification",
#     "name": "arcanum duplicatum"
#   },
#   {
#     "id": "archets_de_violons~product_simplification",
#     "name": "archets de violons"
#   },
#   {
#     "id": "archets_et_violon~product_simplification",
#     "name": "archets et violon"
#   },
#   {
#     "id": "ardoise~product_simplification",
#     "name": "ardoise"
#   },
#   {
#     "id": "ardoise_commune~product_simplification",
#     "name": "ardoise commune"
#   },
#   {
#     "id": "ardoise_dite_ch\u00e9rubin_et_\u00e0_mortier~product_simplification",
#     "name": "ardoise dite ch\u00e9rubin et \u00e0 mortier"
#   },
#   {
#     "id": "ardoise_dite_grande_voisine~product_simplification",
#     "name": "ardoise dite grande voisine"
#   },
#   {
#     "id": "ardoise_dite_moyenne_voisine~product_simplification",
#     "name": "ardoise dite moyenne voisine"
#   },
#   {
#     "id": "ardoise_dite_petite_voisine~product_simplification",
#     "name": "ardoise dite petite voisine"
#   },
#   {
#     "id": "ardoise_dite_voisine_grande_moyenne_et_petite~product_simplification",
#     "name": "ardoise dite voisine grande moyenne et petite"
#   },
#   {
#     "id": "ardoise_en_carreaux~product_simplification",
#     "name": "ardoise en carreaux"
#   },
#   {
#     "id": "ardoise_en_carreaux_et_d'1_pied_carr\u00e9~product_simplification",
#     "name": "ardoise en carreaux et d'1 pied carr\u00e9"
#   },
#   {
#     "id": "ardoise_en_carreaux_ou_en_table~product_simplification",
#     "name": "ardoise en carreaux ou en table"
#   },
#   {
#     "id": "ardoise_en_livret~product_simplification",
#     "name": "ardoise en livret"
#   },
#   {
#     "id": "ardoise_encadr\u00e9e~product_simplification",
#     "name": "ardoise encadr\u00e9e"
#   },
#   {
#     "id": "ardoise_encadr\u00e9e_et_en_livret~product_simplification",
#     "name": "ardoise encadr\u00e9e et en livret"
#   },
#   {
#     "id": "ardoise_non_travaill\u00e9e~product_simplification",
#     "name": "ardoise non travaill\u00e9e"
#   },
#   {
#     "id": "ardoise_pour_fen\u00eatre~product_simplification",
#     "name": "ardoise pour fen\u00eatre"
#   },
#   {
#     "id": "ardoise_pour_toiture~product_simplification",
#     "name": "ardoise pour toiture"
#   },
#   {
#     "id": "ardoise_pour_toiture_au_kilogramme~product_simplification",
#     "name": "ardoise pour toiture au kilogramme"
#   },
#   {
#     "id": "ardoise_pour_toiture_au_nombre~product_simplification",
#     "name": "ardoise pour toiture au nombre"
#   },
#   {
#     "id": "ardoise_verte~product_simplification",
#     "name": "ardoise verte"
#   },
#   {
#     "id": "ardoise_\u00e0_piler~product_simplification",
#     "name": "ardoise \u00e0 piler"
#   },
#   {
#     "id": "ardoises~product_simplification",
#     "name": "ardoises"
#   },
#   {
#     "id": "ardoises_et_ciment_et_chaux_et_pierres_et_pl\u00e2tre_et_pouzzolane_et_sable_et_terre~product_simplification",
#     "name": "ardoises et ciment et chaux et pierres et pl\u00e2tre et pouzzolane et sable et terre"
#   },
#   {
#     "id": "arelles_de_baleine~product_simplification",
#     "name": "arelles de baleine"
#   },
#   {
#     "id": "argent~product_simplification",
#     "name": "argent"
#   },
#   {
#     "id": "argent_battu~product_simplification",
#     "name": "argent battu"
#   },
#   {
#     "id": "argent_battu_et_en_feuille~product_simplification",
#     "name": "argent battu et en feuille"
#   },
#   {
#     "id": "argent_battu_fil\u00e9_lamin\u00e9_et_tir\u00e9~product_simplification",
#     "name": "argent battu fil\u00e9 lamin\u00e9 et tir\u00e9"
#   },
#   {
#     "id": "argent_bris\u00e9_et_en_lingots_et_en_masses~product_simplification",
#     "name": "argent bris\u00e9 et en lingots et en masses"
#   },
#   {
#     "id": "argent_brut~product_simplification",
#     "name": "argent brut"
#   },
#   {
#     "id": "argent_brut_en_lingot_et_en_masse_ouvrages_d\u00e9truits~product_simplification",
#     "name": "argent brut en lingot et en masse ouvrages d\u00e9truits"
#   },
#   {
#     "id": "argent_br\u00fbl\u00e9~product_simplification",
#     "name": "argent br\u00fbl\u00e9"
#   },
#   {
#     "id": "argent_carragoux~product_simplification",
#     "name": "argent carragoux"
#   },
#   {
#     "id": "argent_en_barils~product_simplification",
#     "name": "argent en barils"
#   },
#   {
#     "id": "argent_en_barres~product_simplification",
#     "name": "argent en barres"
#   },
#   {
#     "id": "argent_en_lingots~product_simplification",
#     "name": "argent en lingots"
#   },
#   {
#     "id": "argent_en_lingots_par_Calais~product_simplification",
#     "name": "argent en lingots par Calais"
#   },
#   {
#     "id": "argent_et_or~product_simplification",
#     "name": "argent et or"
#   },
#   {
#     "id": "argent_et_or_billon~product_simplification",
#     "name": "argent et or billon"
#   },
#   {
#     "id": "argent_faux~product_simplification",
#     "name": "argent faux"
#   },
#   {
#     "id": "argent_faux_en_fil_cantilles_etc.~product_simplification",
#     "name": "argent faux en fil cantilles etc."
#   },
#   {
#     "id": "argent_faux_et_or_faux~product_simplification",
#     "name": "argent faux et or faux"
#   },
#   {
#     "id": "argent_faux_et_or_faux_traits~product_simplification",
# ...
#     "name": "\u00e9toffe finette"
#   },
#   {
#     "id": "\u00e9toffe_flamande_de_mauvaise_qualit\u00e9~product_simplification",
#     "name": "\u00e9toffe flamande de mauvaise qualit\u00e9"
#   },
#   {
#     "id": "\u00e9toffe_fleuret~product_simplification",
#     "name": "\u00e9toffe fleuret"
#   },
#   {
#     "id": "\u00e9toffe_fleuret_et_de_soie~product_simplification",
#     "name": "\u00e9toffe fleuret et de soie"
#   },
#   {
#     "id": "\u00e9toffe_fleuret_et_soie~product_simplification",
#     "name": "\u00e9toffe fleuret et soie"
#   },
#   {
#     "id": "\u00e9toffe_flotte~product_simplification",
#     "name": "\u00e9toffe flotte"
#   },
#   {
#     "id": "\u00e9toffe_flotte_des_Indes~product_simplification",
#     "name": "\u00e9toffe flotte des Indes"
#   },
#   {
#     "id": "\u00e9toffe_grosse_de_laine~product_simplification",
#     "name": "\u00e9toffe grosse de laine"
#   },
#   {
#     "id": "\u00e9toffe_herbage~product_simplification",
#     "name": "\u00e9toffe herbage"
#   },
#   {
#     "id": "\u00e9toffe_herbes~product_simplification",
#     "name": "\u00e9toffe herbes"
#   },
#   {
#     "id": "\u00e9toffe_imp\u00e9riale~product_simplification",
#     "name": "\u00e9toffe imp\u00e9riale"
#   },
#   {
#     "id": "\u00e9toffe_laine_de_soie~product_simplification",
#     "name": "\u00e9toffe laine de soie"
#   },
#   {
#     "id": "\u00e9toffe_manchettes~product_simplification",
#     "name": "\u00e9toffe manchettes"
#   },
#   {
#     "id": "\u00e9toffe_mi_soie~product_simplification",
#     "name": "\u00e9toffe mi soie"
#   },
#   {
#     "id": "\u00e9toffe_m\u00eal\u00e9e_au_???_soie~product_simplification",
#     "name": "\u00e9toffe m\u00eal\u00e9e au ??? soie"
#   },
#   {
#     "id": "\u00e9toffe_m\u00eal\u00e9e_de_bourre_en_molleton~product_simplification",
#     "name": "\u00e9toffe m\u00eal\u00e9e de bourre en molleton"
#   },
#   {
#     "id": "\u00e9toffe_m\u00eal\u00e9e_de_fil_de_soie~product_simplification",
#     "name": "\u00e9toffe m\u00eal\u00e9e de fil de soie"
#   },
#   {
#     "id": "\u00e9toffe_m\u00eal\u00e9e_de_soie~product_simplification",
#     "name": "\u00e9toffe m\u00eal\u00e9e de soie"
#   },
#   {
#     "id": "\u00e9toffe_m\u00eal\u00e9e_de_soie_???~product_simplification",
#     "name": "\u00e9toffe m\u00eal\u00e9e de soie ???"
#   },
#   {
#     "id": "\u00e9toffe_m\u00eal\u00e9e_de_soie_peluches~product_simplification",
#     "name": "\u00e9toffe m\u00eal\u00e9e de soie peluches"
#   },
#   {
#     "id": "\u00e9toffe_noire~product_simplification",
#     "name": "\u00e9toffe noire"
#   },
#   {
#     "id": "\u00e9toffe_peinte~product_simplification",
#     "name": "\u00e9toffe peinte"
#   },
#   {
#     "id": "\u00e9toffe_peluches_communes~product_simplification",
#     "name": "\u00e9toffe peluches communes"
#   },
#   {
#     "id": "\u00e9toffe_peluches_de_laine~product_simplification",
#     "name": "\u00e9toffe peluches de laine"
#   },
#   {
#     "id": "\u00e9toffe_peluches_de_prise~product_simplification",
#     "name": "\u00e9toffe peluches de prise"
#   },
#   {
#     "id": "\u00e9toffe_peluches_de_soie~product_simplification",
#     "name": "\u00e9toffe peluches de soie"
#   },
#   {
#     "id": "\u00e9toffe_poil_en_panne_\u00e0_long_poil~product_simplification",
#     "name": "\u00e9toffe poil en panne \u00e0 long poil"
#   },
#   {
#     "id": "\u00e9toffe_pour_talits~product_simplification",
#     "name": "\u00e9toffe pour talits"
#   },
#   {
#     "id": "\u00e9toffe_pure_broch\u00e9e_d'or_fin~product_simplification",
#     "name": "\u00e9toffe pure broch\u00e9e d'or fin"
#   },
#   {
#     "id": "\u00e9toffe_pure_fa\u00e7onn\u00e9e~product_simplification",
#     "name": "\u00e9toffe pure fa\u00e7onn\u00e9e"
#   },
#   {
#     "id": "\u00e9toffe_pure_unie~product_simplification",
#     "name": "\u00e9toffe pure unie"
#   },
#   {
#     "id": "\u00e9toffe_pures_de_fleuret_et_mouchoirs~product_simplification",
#     "name": "\u00e9toffe pures de fleuret et mouchoirs"
#   },
#   {
#     "id": "\u00e9toffe_refoul\u00e9e~product_simplification",
#     "name": "\u00e9toffe refoul\u00e9e"
#   },
#   {
#     "id": "\u00e9toffe_riche~product_simplification",
#     "name": "\u00e9toffe riche"
#   },
#   {
#     "id": "\u00e9toffe_riche_en_or~product_simplification",
#     "name": "\u00e9toffe riche en or"
#   },
#   {
#     "id": "\u00e9toffe_riche_en_or_et_argent~product_simplification",
#     "name": "\u00e9toffe riche en or et argent"
#   },
#   {
#     "id": "\u00e9toffe_riche_or_et_argent~product_simplification",
#     "name": "\u00e9toffe riche or et argent"
#   },
#   {
#     "id": "\u00e9toffe_riche_ou_or_et_argent~product_simplification",
#     "name": "\u00e9toffe riche ou or et argent"
#   },
#   {
#     "id": "\u00e9toffe_royale~product_simplification",
#     "name": "\u00e9toffe royale"
#   },
#   {
#     "id": "\u00e9toffe_soie_cr\u00eape~product_simplification",
#     "name": "\u00e9toffe soie cr\u00eape"
#   },
#   {
#     "id": "\u00e9toffe_soie_des_Indes~product_simplification",
#     "name": "\u00e9toffe soie des Indes"
#   },
#   {
#     "id": "\u00e9toffe_soierie~product_simplification",
#     "name": "\u00e9toffe soierie"
#   },
#   {
#     "id": "\u00e9toffe_taffetas~product_simplification",
#     "name": "\u00e9toffe taffetas"
#   },
#   {
#     "id": "\u00e9toffe_\u00e0_carreaux~product_simplification",
#     "name": "\u00e9toffe \u00e0 carreaux"
#   },
#   {
#     "id": "\u00e9toffe_\u00e0_carreaux_et_de_toile_de_coutil~product_simplification",
#     "name": "\u00e9toffe \u00e0 carreaux et de toile de coutil"
#   },
#   {
#     "id": "\u00e9toffe_\u00e0_galon_d'or~product_simplification",
#     "name": "\u00e9toffe \u00e0 galon d'or"
#   },
#   {
#     "id": "\u00e9toffe_\u00e0_la_valeur~product_simplification",
#     "name": "\u00e9toffe \u00e0 la valeur"
#   },
#   {
#     "id": "\u00e9toffe_\u00e0_peu_de_soie~product_simplification",
#     "name": "\u00e9toffe \u00e0 peu de soie"
#   },
#   {
#     "id": "\u00c9toffe_\u00e9tamine_fine~product_simplification",
#     "name": "\u00c9toffe \u00e9tamine fine"
#   },
#   {
#     "id": "\u00e9toffe_\u00e9ternelle~product_simplification",
#     "name": "\u00e9toffe \u00e9ternelle"
#   },
#   {
#     "id": "\u00e9toffe_\u00e9ternelle_au_?_de_soie~product_simplification",
#     "name": "\u00e9toffe \u00e9ternelle au ? de soie"
#   },
#   {
#     "id": "\u00e9toffe_\u00e9ternelle_de_laine~product_simplification",
#     "name": "\u00e9toffe \u00e9ternelle de laine"
#   },
#   {
#     "id": "\u00e9toffe_\u00e9ternelle_m\u00eal\u00e9e_de_soie~product_simplification",
#     "name": "\u00e9toffe \u00e9ternelle m\u00eal\u00e9e de soie"
#   },
#   {
#     "id": "\u00e9toffe_\u00e9trang\u00e8re~product_simplification",
#     "name": "\u00e9toffe \u00e9trang\u00e8re"
#   },
#   {
#     "id": "\u00e9toffe_\u00e9trang\u00e8re_de_jude~product_simplification",
#     "name": "\u00e9toffe \u00e9trang\u00e8re de jude"
#   },
#   {
#     "id": "\u00e9toupes~product_simplification",
#     "name": "\u00e9toupes"
#   },
#   {
#     "id": "\u00e9toupes_blanches~product_simplification",
#     "name": "\u00e9toupes blanches"
#   },
#   {
#     "id": "\u00e9toupes_de_chanvre~product_simplification",
#     "name": "\u00e9toupes de chanvre"
#   },
#   {
#     "id": "\u00e9toupes_de_coton~product_simplification",
#     "name": "\u00e9toupes de coton"
#   },
#   {
#     "id": "\u00e9toupes_de_filoselle~product_simplification",
#     "name": "\u00e9toupes de filoselle"
#   },
#   {
#     "id": "\u00e9toupes_de_laine~product_simplification",
#     "name": "\u00e9toupes de laine"
#   },
#   {
#     "id": "\u00e9toupes_de_lin~product_simplification",
#     "name": "\u00e9toupes de lin"
#   },
#   {
#     "id": "\u00e9toupes_de_soie~product_simplification",
#     "name": "\u00e9toupes de soie"
#   },
#   {
#     "id": "\u00e9toupes_de_vieux_cordages~product_simplification",
#     "name": "\u00e9toupes de vieux cordages"
#   },
#   {
#     "id": "\u00e9toupes_et_cordes_de_lin~product_simplification",
#     "name": "\u00e9toupes et cordes de lin"
#   },
#   {
#     "id": "\u00e9toupes_noires~product_simplification",
#     "name": "\u00e9toupes noires"
#   },
#   {
#     "id": "\u00e9toupes_\u00e0_calfater~product_simplification",
#     "name": "\u00e9toupes \u00e0 calfater"
#   },
#   {
#     "id": "\u00e9triers~product_simplification",
#     "name": "\u00e9triers"
#   },
#   {
#     "id": "\u00e9trille_de_fer~product_simplification",
#     "name": "\u00e9trille de fer"
#   },
#   {
#     "id": "\u00e9trilles~product_simplification",
#     "name": "\u00e9trilles"
#   },
#   {
#     "id": "\u00e9tuis~product_simplification",
#     "name": "\u00e9tuis"
#   },
#   {
#     "id": "\u00e9tuis_d'or~product_simplification",
#     "name": "\u00e9tuis d'or"
#   },
#   {
#     "id": "\u00e9tuis_d'or_en_burgos~product_simplification",
#     "name": "\u00e9tuis d'or en burgos"
#   },
#   {
#     "id": "\u00e9tuis_de_bergamote~product_simplification",
#     "name": "\u00e9tuis de bergamote"
#   },
#   {
#     "id": "\u00e9tuis_de_bois_et_\u00e9tuis_de_paille_et_bo\u00eetes_de_papier~product_simplification",
#     "name": "\u00e9tuis de bois et \u00e9tuis de paille et bo\u00eetes de papier"
#   },
#   {
#     "id": "\u00e9tuis_de_carton~product_simplification",
#     "name": "\u00e9tuis de carton"
#   },
#   {
#     "id": "\u00e9tuis_de_chapeaux~product_simplification",
#     "name": "\u00e9tuis de chapeaux"
#   },
#   {
#     "id": "\u00e9tuis_de_chirurgie~product_simplification",
#     "name": "\u00e9tuis de chirurgie"
#   },
#   {
#     "id": "\u00e9tuis_de_ciseaux_garnis_d'argent~product_simplification",
#     "name": "\u00e9tuis de ciseaux garnis d'argent"
#   },
#   {
#     "id": "\u00e9tuis_de_math\u00e9matique~product_simplification",
#     "name": "\u00e9tuis de math\u00e9matique"
#   },
#   {
#     "id": "\u00e9tuis_et_tabati\u00e8res_et_autres_bijouteries_garnies_d'argent_et_d'or~product_simplification",
#     "name": "\u00e9tuis et tabati\u00e8res et autres bijouteries garnies d'argent et d'or"
#   },
#   {
#     "id": "\u00e9tuis_et_tabati\u00e8res_garnis_d'argent~product_simplification",
#     "name": "\u00e9tuis et tabati\u00e8res garnis d'argent"
#   },
#   {
#     "id": "\u00e9tuis_et_tabati\u00e8res_garnis_d'argent_et_d'or~product_simplification",
#     "name": "\u00e9tuis et tabati\u00e8res garnis d'argent et d'or"
#   },
#   {
#     "id": "\u00e9tuis_et_tabati\u00e8res_garnis_d'or~product_simplification",
#     "name": "\u00e9tuis et tabati\u00e8res garnis d'or"
#   },
#   {
#     "id": "\u00e9tuis_garnis~product_simplification",
#     "name": "\u00e9tuis garnis"
#   },
#   {
#     "id": "\u00e9tuis_pour_plumes_\u00e0_\u00e9crire~product_simplification",
#     "name": "\u00e9tuis pour plumes \u00e0 \u00e9crire"
#   },
#   {
#     "id": "\u00e9tuis_\u00e0_cachets~product_simplification",
#     "name": "\u00e9tuis \u00e0 cachets"
#   },
#   {
#     "id": "\u00e9tuis_\u00e0_cure-dents~product_simplification",
#     "name": "\u00e9tuis \u00e0 cure-dents"
#   },
#   {
#     "id": "\u00e9tuis_\u00e0_lunettes~product_simplification",
#     "name": "\u00e9tuis \u00e0 lunettes"
#   },
#   {
#     "id": "\u00e9tuve~product_simplification",
#     "name": "\u00e9tuve"
#   },
#   {
#     "id": "\u00e9tuve_commune~product_simplification",
#     "name": "\u00e9tuve commune"
#   },
#   {
#     "id": "\u00e9tuve_de_cuivre~product_simplification",
#     "name": "\u00e9tuve de cuivre"
#   },
#   {
#     "id": "\u00e9tuve_de_fer~product_simplification",
#     "name": "\u00e9tuve de fer"
#   },
#   {
#     "id": "\u00e9tuve_de_fer_\u00e0_sucre~product_simplification",
#     "name": "\u00e9tuve de fer \u00e0 sucre"
#   },
#   {
#     "id": "\u00e9ventails~product_simplification",
#     "name": "\u00e9ventails"
#   },
#   {
#     "id": "\u00e9ventails_communs~product_simplification",
#     "name": "\u00e9ventails communs"
#   },
#   {
#     "id": "\u00e9ventails_d'ivoire~product_simplification",
#     "name": "\u00e9ventails d'ivoire"
#   },
#   {
#     "id": "\u00e9ventails_d'ivoire_fin~product_simplification",
#     "name": "\u00e9ventails d'ivoire fin"
#   },
#   {
#     "id": "\u00e9ventails_d'or~product_simplification",
#     "name": "\u00e9ventails d'or"
#   },
#   {
#     "id": "\u00e9ventails_d'os~product_simplification",
#     "name": "\u00e9ventails d'os"
#   },
#   {
#     "id": "\u00e9ventails_d'\u00e9caille_et_d'ivoire_et_de_nacre~product_simplification",
#     "name": "\u00e9ventails d'\u00e9caille et d'ivoire et de nacre"
#   },
#   {
#     "id": "\u00e9ventails_de_la_Chine~product_simplification",
#     "name": "\u00e9ventails de la Chine"
#   },
#   {
#     "id": "\u00e9ventails_de_nacre~product_simplification",
#     "name": "\u00e9ventails de nacre"
#   },
#   {
#     "id": "\u00e9ventails_de_paille~product_simplification",
#     "name": "\u00e9ventails de paille"
#   },
#   {
#     "id": "\u00e9ventails_de_palmes~product_simplification",
#     "name": "\u00e9ventails de palmes"
#   },
#   {
#     "id": "\u00e9ventails_de_papier~product_simplification",
#     "name": "\u00e9ventails de papier"
#   },
#   {
#     "id": "\u00e9ventails_de_plume~product_simplification",
#     "name": "\u00e9ventails de plume"
#   },
#   {
#     "id": "\u00e9ventails_de_porcelaine~product_simplification",
#     "name": "\u00e9ventails de porcelaine"
#   },
#   {
#     "id": "\u00e9ventails_de_taffetas~product_simplification",
#     "name": "\u00e9ventails de taffetas"
#   },
#   {
#     "id": "\u00e9ventails_des_Indes~product_simplification",
#     "name": "\u00e9ventails des Indes"
#   },
#   {
#     "id": "\u00e9ventails_et_papier_dito~product_simplification",
#     "name": "\u00e9ventails et papier dito"
#   },
#   {
#     "id": "\u00e9ventails_fins~product_simplification",
#     "name": "\u00e9ventails fins"
#   },
#   {
#     "id": "\u00e9ventails_fins_et_d'ivoire~product_simplification",
#     "name": "\u00e9ventails fins et d'ivoire"
#   },
#   {
#     "id": "\u00e9ventails_incrust\u00e9s_d'or_et_de_nacre_de_perles~product_simplification",
#     "name": "\u00e9ventails incrust\u00e9s d'or et de nacre de perles"
#   },
#   {
#     "id": "\u00e9ventails_par_douzaines~product_simplification",
#     "name": "\u00e9ventails par douzaines"
#   },
#   {
#     "id": "\u00e9ventails_sur_\u00e9caille~product_simplification",
#     "name": "\u00e9ventails sur \u00e9caille"
#   },
#   {
#     "id": "\u00e9ventails_\u00e0_brin_d'ivoire_et_\u00e9caille~product_simplification",
#     "name": "\u00e9ventails \u00e0 brin d'ivoire et \u00e9caille"
#   },
#   {
#     "id": "\u00e9ventails_\u00e0_brin_d'os_et_\u00e9caille~product_simplification",
#     "name": "\u00e9ventails \u00e0 brin d'os et \u00e9caille"
#   },
#   {
#     "id": "\u00e9ventails_\u00e0_feuille_de_soie~product_simplification",
#     "name": "\u00e9ventails \u00e0 feuille de soie"
#   },
#   {
#     "id": "\u00e9ventails_\u00e0_feuilles_communes~product_simplification",
#     "name": "\u00e9ventails \u00e0 feuilles communes"
#   },
#   {
#     "id": "\u00e9viers~product_simplification",
#     "name": "\u00e9viers"
#   },
#   {
#     "id": "\u0153il_de_b\u0153uf~product_simplification",
#     "name": "\u0153il de b\u0153uf"
#   },
#   {
#     "id": "\u0153il_de_b\u0153uf_garni_de_cuivre~product_simplification",
#     "name": "\u0153il de b\u0153uf garni de cuivre"
#   },
#   {
#     "id": "\u0153illards~product_simplification",
#     "name": "\u0153illards"
#   },
#   {
#     "id": "\u0153illards_de_Brie~product_simplification",
#     "name": "\u0153illards de Brie"
#   },
#   {
#     "id": "\u0153illets~product_simplification",
#     "name": "\u0153illets"
#   },
#   {
#     "id": "\u0153ufs~product_simplification",
#     "name": "\u0153ufs"
#   },
#   {
#     "id": "\u0153ufs_15_ou_16_au_kilogramme~product_simplification",
#     "name": "\u0153ufs 15 ou 16 au kilogramme"
#   },
#   {
#     "id": "\u0153ufs_d'autruche~product_simplification",
#     "name": "\u0153ufs d'autruche"
#   },
#   {
#     "id": "\u0153ufs_de_composition~product_simplification",
#     "name": "\u0153ufs de composition"
#   },
#   {
#     "id": "\u0153ufs_de_faisan~product_simplification",
#     "name": "\u0153ufs de faisan"
#   },
#   {
#     "id": "\u0153ufs_de_gibier_et_de_volaille~product_simplification",
#     "name": "\u0153ufs de gibier et de volaille"
#   },
#   {
#     "id": "\u0153ufs_de_perdrix_rouge~product_simplification",
#     "name": "\u0153ufs de perdrix rouge"
#   },
#   {
#     "id": "\u0153ufs_de_poisson~product_simplification",
#     "name": "\u0153ufs de poisson"
#   },
#   {
#     "id": "\u0153ufs_de_poule~product_simplification",
#     "name": "\u0153ufs de poule"
#   },
#   {
#     "id": "\u0153ufs_de_thon~product_simplification",
#     "name": "\u0153ufs de thon"
#   },
#   {
#     "id": "\u0153ufs_de_volaille~product_simplification",
#     "name": "\u0153ufs de volaille"
#   },
#   {
#     "id": "\u0153ufs_et_volaille~product_simplification",
#     "name": "\u0153ufs et volaille"
#   }
# ]

# %% [markdown]
# Fonctions à ajouter :
#
# * liste des types de sources
# * liste des classifications de partenaires
# * liste des classifications de produits
